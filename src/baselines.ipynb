# %%
import os
os.environ['COCO_DIR'] = 'coco2017/'
os.environ['AOKVQA_DIR'] = '/usr1/data/mingqia2/aokvqa/'
os.environ['HF_HOME'] = '/usr1/data/models_cache'
import json
import numpy as np
import pandas as pd
from tqdm import tqdm
import re
import random

from PIL import Image
import requests
import torch

from transformers import AutoModelForCausalLM, AutoProcessor, GenerationConfig, LlavaForConditionalGeneration 
from transformers import Blip2Processor, Blip2ForConditionalGeneration
from transformers import AddedToken


from load_aokvqa import load_aokvqa, get_coco_path

# %%
coco_dir = os.getenv('COCO_DIR')
aokvqa_dir = os.getenv('AOKVQA_DIR')
val_dataset = load_aokvqa(aokvqa_dir, 'val')

# %%
def save_results_to_file(results, output_file):
    with open(output_file, 'w') as f:
        json.dump(results, f)

# %%
def extract_answer(answer_text):
    assistant_marker = "ASSISTANT:"
    start_idx = answer_text.find(assistant_marker)
    if start_idx != -1:
        # Extract the portion after "ASSISTANT:" and strip any leading/trailing whitespace
        return answer_text[start_idx + len(assistant_marker):].strip()
    else:
        # Return None if "ASSISTANT:" is not found
        return None
    
def process_results(output_file, dataset, model='llava', mc=False):
    with open(output_file, 'r') as f:
        results = json.load(f)
    for result, item in zip(results, dataset):
        if model == 'llava':
            result['answer'] = extract_answer(result['answer'])
        elif model == 'blip':
            result['answer'] = result['answer'].strip()
        else:
            print("Model not recognized!")
        
        if mc:
            result['correct_choice_idx'] = item['correct_choice_idx']
        else:
            result['direct_answers'] = item['direct_answers']
    return results

# %%
def eval_vqa(val_result, val_dataset, seed=42, mc=False):
    random.seed(seed)
    acc = []
    for result, item in zip(val_result, val_dataset):
        image_id = result['image_id']
        question_id = result['question_id']
        pred = result['answer'].lower()
        if item['image_id'] == image_id and item['question_id'] == question_id:
            direct_answers = item['direct_answers']
            if mc:
                pred = re.search(r'\d+', result['answer'])
                if pred in ['1', '2', '3', '4']:
                    pred = int(pred)
                else:
                    pred = random.randint(1, 4)
                acc.append(1) if pred == (item['correct_choice_idx']+1) else acc.append(0) 
            else:
                num_match = sum([pred == da for da in direct_answers])
                vqa_acc = min(1.0, num_match / 3.0)
                acc.append(vqa_acc)
        else:
            print(f"Image ID or question ID mismatch: {image_id}, {question_id}")
    acc = sum(acc) / len(acc) * 100
    return acc

# %% [markdown]
# # Q&A Prompts
# Git Repo: https://github.com/WHB139426/QA-Prompts

# %% [markdown]
# # BLIP-2

# %%
def blip_pipeline(processor, model, val_dataset, coco_dir, output_file, batch_size=100, split='val', mc=False):
    results = []
    total_items = len(val_dataset)
    
    for idx, item in tqdm(enumerate(val_dataset), total=len(val_dataset)):
        image_id = item['image_id']
        question_id = item['question_id']
        if mc:
            choices = item['choices']
            choices_formatted = " ".join([f"({i+1}) {choice}" for i, choice in enumerate(choices)])
            question = item['question'] + " " + choices_formatted + " Please return only the chosen choice number (1, 2, 3, or 4) as the answer."
        else:
            question = item['question'] + " Please return only the key word or phrase as the answer, not a full sentence."
        
        image_path = get_coco_path(split, image_id, coco_dir)

        # Load the image from the local path
        raw_image = Image.open(image_path)
        prompt = f"Question: {question} Answer:"
        inputs = processor(images=raw_image, text=prompt, return_tensors='pt').to(device="cuda",dtype=torch.float16)

        # Run the model and generate output
        output = model.generate(**inputs, max_new_tokens=10, do_sample=False)
        decoded_output = processor.decode(output[0][2:], skip_special_tokens=True)

        # Store the results
        result = {
            "image_id": image_id,
            "question_id": question_id,
            "answer": decoded_output
        }
        results.append(result)

        if (idx + 1) % batch_size == 0 or (idx + 1) == total_items:
            save_results_to_file(results, output_file)
    # return results

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
processor = Blip2Processor.from_pretrained("Salesforce/blip2-opt-2.7b")
model = Blip2ForConditionalGeneration.from_pretrained("Salesforce/blip2-opt-2.7b",device_map={"": 0}, torch_dtype=torch.float16)

processor.num_query_tokens = model.config.num_query_tokens
image_token = AddedToken("", normalized=False, special=True)
processor.tokenizer.add_tokens([image_token], special_tokens=True)

model.resize_token_embeddings(len(processor.tokenizer), pad_to_multiple_of=64) # pad for efficient computation
model.config.image_token_index = len(processor.tokenizer) - 1
# Out:
# Loading checkpoint shards: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]

# %%
output_file = 'blip2-opt-2.7b_val_results_da.json'
blip_pipeline(processor, model, val_dataset, coco_dir, output_file, batch_size=100, split='val')
# Out:
# 100%|██████████| 1145/1145 [01:25<00:00, 13.43it/s]

# %%
output_file = 'blip2-opt-2.7b_val_results_mc.json'
blip_pipeline(processor, model, val_dataset, coco_dir, output_file, batch_size=100, split='val', mc=True)
# Out:
# 100%|██████████| 1145/1145 [02:27<00:00,  7.74it/s]

# %%
blip_mc_result = process_results('blip2-opt-2.7b_val_results_mc.json', val_dataset, model='blip', mc=True)
blip_da_result = process_results('blip2-opt-2.7b_val_results_da.json', val_dataset, model='blip')

# %%
blip_da_result
# Out:
# [{'image_id': 461751,
#   'question_id': '22jbM6gDxdaMaunuzgrsBB',
#   'answer': 'cigarette',
#   'direct_answers': ['cigarette',
#    'cigarette',
#    'cigarette',
#    'cigarette',
#    'cigarette',
#    'cigarette',
#    'cigarette',
#    'cigarette',
#    'cigarette',
#    'cigarette']},
#  {'image_id': 377368,
#   'question_id': '2Aq5RiEn7eyfWjEbpuYT2o',
#   'answer': '',
#   'direct_answers': ['thirty',
#    '30th',
#    'thirty',
#    'thirty',
#    'thirty',
#    '30th',
#    'thirty',
#    'thirty',
#    'thirty',
#    'thirty']},
#  {'image_id': 563603,
#   'question_id': '2Br4bJfKY7SQM9DECrqqeG',
#   'answer': '',
#   'direct_answers': ['muddy',
#    'dirty',
#    'murky water',
#    'muddy',
#    'pond',
#    'pond',
#    'watering hole',
#    'pond',
#    'pond',
#    'dirty']},
#  {'image_id': 329542,
#   'question_id': '2C8riXpRLX3CyM5jDz23m7',
#   'answer': 'ing',
#   'direct_answers': ['icing',
#    'whipped cream',
#    'icing',
#    'frosting',
#    'icing',
#    'frosting',
#    'cream',
#    'icing',
#    'icing',
#    'frosting']},
#  {'image_id': 182202,
#   'question_id': '2DQex53EkNGH2cfo3WPuPn',
#   'answer': 'cell phone',
#   'direct_answers': ['cell phone',
#    'vodafone',
#    'phone',
#    'phone',
#    'phone',
#    'phone',
#    'cell phone',
#    'phone',
#    'phone',
#    'mobile phone']},
#  {'image_id': 198960,
#   'question_id': '2GhdXLaZFBYHSip4rvYKfK',
#   'answer': '',
#   'direct_answers': ['different ear',
#    'he goat',
#    'elephant',
#    'bull',
#    'devil',
#    'rams',
#    'ram',
#    'buck',
#    'horns',
#    'sheep']},
#  {'image_id': 257169,
#   'question_id': '2LCLpdpD3yy2dgH5tQbcFe',
#   'answer': 'dryer',
#   'direct_answers': ['drying hair',
#    'combing hair',
#    'drying hair',
#    'blowing hair',
#    'hair drying',
#    'steamer',
#    'hair styling',
#    'dryer',
#    'hairdryer',
#    'hair drying']},
#  {'image_id': 4795,
#   'question_id': '2N5sYXgyFqbDnuUhJFAWr5',
#   'answer': '',
#   'direct_answers': ['desk',
#    'desktop',
#    'glossy',
#    'computer',
#    'busy',
#    'crowded',
#    'table',
#    'smooth',
#    'desk',
#    'cluttered']},
#  {'image_id': 341196,
#   'question_id': '2P5mVJc5a6DcCN9opV92FJ',
#   'answer': 'fing',
#   'direct_answers': ['surfing',
#    'surfing',
#    'crouching',
#    'surfing',
#    'surfing',
#    'ducking',
#    'bending',
#    'crouching',
#    'surfing',
#    'surfing']},
#  {'image_id': 163640,
#   'question_id': '2PGwvdFESLvwfFCwK5pbYu',
#   'answer': '',
#   'direct_answers': ['jeans',
#    'blue jeans',
#    'jeans',
#    'denim',
#    'jeans',
#    'jeans',
#    'jeans',
#    'jeans',
#    'jeans',
#    'blue jeans']},
#  {'image_id': 71711,
#   'question_id': '2RN4dwhRZR3ZSKHtRnJdX3',
#   'answer': '',
#   'direct_answers': ['united states',
#    'united states',
#    'usa',
#    'united states',
#    'united states',
#    'ukraine',
#    'germany',
#    'germany',
#    'america',
#    'usa']},
#  {'image_id': 117425,
#   'question_id': '2U3SiXdyEgJBHNThL4YbPz',
#   'answer': 'child is looking at the candle',
#   'direct_answers': ['candle',
#    'cake',
#    'candle flame',
#    'cupcake',
#    'candle',
#    'flame',
#    'fire',
#    'candle',
#    'cupcake',
#    'candle']},
#  {'image_id': 250766,
#   'question_id': '2YfYkRjcnnsVzjycPehWPA',
#   'answer': 'berries',
#   'direct_answers': ['grape',
#    'tomato',
#    'tomato',
#    'grapes',
#    'dates',
#    'grapes',
#    'grapes',
#    'dates',
#    'olive',
#    'tomato']},
#  {'image_id': 147415,
#   'question_id': '2etjUMchktfSY5fgGg5msL',
#   'answer': 'blanket',
#   'direct_answers': ['cough drops',
#    'tissue',
#    'ricola',
#    'cough drops',
#    'tissue box',
#    'ricola',
#    'cough drops',
#    'tissue',
#    'tissue',
#    'tissues']},
#  {'image_id': 434459,
#   'question_id': '2oPzCyj5FjrKtBLjGZH2rF',
#   'answer': '',
#   'direct_answers': ["don't know",
#    'american',
#    'american',
#    'usa',
#    'cuba',
#    'united states',
#    'united states',
#    'american',
#    'usa',
#    'usa']},
#  {'image_id': 421923,
#   'question_id': '2rC38fZh4n6ZXcyrUEKukj',
#   'answer': 'vase of daisies',
#   'direct_answers': ['books',
#    'books',
#    'books',
#    'books',
#    'books',
#    'books',
#    'books',
#    'books',
#    'books',
#    'books']},
#  {'image_id': 245173,
#   'question_id': '2sUggWn8qBk97E38wKpjN5',
#   'answer': '',
#   'direct_answers': ['afternoon',
#    'evening',
#    'evening',
#    'evening',
#    'daytime',
#    'evening',
#    'midday',
#    'afternoon',
#    'afternoon',
#    'noon']},
#  {'image_id': 407960,
#   'question_id': '2vGs6CLETM2BJPstdHjku9',
#   'answer': '',
#   'direct_answers': ['jump',
#    'jump',
#    'watching television',
#    'jump',
#    'eat food',
#    'jump',
#    'jump',
#    'jump',
#    'beg',
#    'eat']},
#  {'image_id': 405691,
#   'question_id': '2wbNBVZMGZnVpYohDAed8d',
#   'answer': '',
#   'direct_answers': ['dinner',
#    'meal',
#    'dinner',
#    'dinner',
#    'celebration',
#    'christmas',
#    'dinner',
#    'date',
#    'dinner',
#    'dinner']},
#  {'image_id': 180878,
#   'question_id': '2xDeTCXSRqdhvREBDhHsMx',
#   'answer': '',
#   'direct_answers': ['frosting',
#    'icing',
#    'food paste',
#    'fondant',
#    'fondant',
#    'icing',
#    'fondant',
#    'icing',
#    'next word',
#    'fondant']},
#  {'image_id': 470773,
#   'question_id': '2xn24MrfJ2mLJC7xDBGUJA',
#   'answer': '',
#   'direct_answers': ['chef uniform',
#    'chef',
#    'cooks uniform',
#    'chef',
#    'chef',
#    'chef',
#    'chef coat',
#    'chef',
#    'chef',
#    'food']},
#  {'image_id': 185250,
#   'question_id': '2yWyzYRyZuYH2ZB49WNACa',
#   'answer': 'isbee',
#   'direct_answers': ['frisbee',
#    'frisbee',
#    'frisbee',
#    'frisbee',
#    'frisbee',
#    'frisbee',
#    'frisbee',
#    'frisbee',
#    'frisbee',
#    'frisbee']},
#  {'image_id': 519764,
#   'question_id': '2zTqTkKqa89GUKLzMUkDic',
#   'answer': '',
#   'direct_answers': ['human',
#    'human',
#    'human',
#    'person',
#    'human',
#    'human',
#    'human',
#    'person',
#    'human',
#    'human']},
#  {'image_id': 562818,
#   'question_id': '34ah8AmQenWUyH2fZvJH7a',
#   'answer': 'resort',
#   'direct_answers': ['ski resort',
#    'skiing',
#    'ski resort',
#    'ski resort',
#    'ski resort',
#    'ski',
#    'ski',
#    'ski',
#    'ski',
#    'snow']},
#  {'image_id': 497568,
#   'question_id': '399Vdu2QjamF3vheUvbRg2',
#   'answer': 'plane',
#   'direct_answers': ['airplane',
#    'airplane',
#    'airplane',
#    'airplane',
#    'air',
#    'air',
#    'airplane',
#    'plane',
#    'airplane',
#    'airplane']},
#  {'image_id': 47121,
#   'question_id': '39CcpmwATuiwiZLZo3XMuv',
#   'answer': 'cat is looking in the direction of the sink',
#   'direct_answers': ['down',
#    'down',
#    'down',
#    'down',
#    'down',
#    'down',
#    'ahead',
#    'ahead',
#    'down',
#    'down']},
#  {'image_id': 485237,
#   'question_id': '3R6SnZ4MRGXXvao5ARVE8e',
#   'answer': '',
#   'direct_answers': ['air traffic',
#    'guide planes',
#    'pulling plane',
#    'safety vehicle',
#    'service airplanes',
#    'transport',
#    'maintenance',
#    'food delivery',
#    'luggage',
#    'maintenance']},
#  {'image_id': 445792,
#   'question_id': '3SKKn3bQ4xhiDpkesifdod',
#   'answer': 'States',
#   'direct_answers': ['japan',
#    'sumsung',
#    'japan',
#    'japan',
#    'japan',
#    'china',
#    'japan',
#    'china',
#    'japan',
#    'japan']},
#  {'image_id': 312192,
#   'question_id': '3X8TsFBRS7mBsBbyFDzRdb',
#   'answer': '',
#   'direct_answers': ['ketchup',
#    'salad',
#    'fish',
#    'ham',
#    'apple',
#    'marshmallow',
#    'pineapple',
#    'water',
#    'pepperoni',
#    'grapes']},
#  {'image_id': 55022,
#   'question_id': '3asRExdxmWQtJw4sv49AGZ',
#   'answer': 'bike',
#   'direct_answers': ['building',
#    'woman',
#    'woman',
#    'dirt',
#    'ground',
#    'closed doors',
#    'flower wreath',
#    'bike',
#    'woman',
#    'not applicable']},
#  {'image_id': 139099,
#   'question_id': '3cCvfCWnLfrmqYEaFzb2Xm',
#   'answer': 'a market',
#   'direct_answers': ['outdoor market',
#    'market',
#    'market',
#    'market',
#    'market',
#    'street festival',
#    'event',
#    'market',
#    'market',
#    'street']},
#  {'image_id': 308394,
#   'question_id': '3echacwmLBUByWpjh85Mfv',
#   'answer': 'person',
#   'direct_answers': ['bag',
#    'bag',
#    'white bag',
#    'shopping bag',
#    'plastic bag',
#    'plastic bag',
#    'plastic bag',
#    'bag',
#    'bag',
#    'bag']},
#  {'image_id': 200421,
#   'question_id': '3ef8KXbKoJaJZyVmxVZMaq',
#   'answer': 'Happy Birthday"',
#   'direct_answers': ['happy birthday',
#    'happy birthday',
#    'happy birthday',
#    'happy birthday',
#    'happy birthday',
#    'happy birthday',
#    'happy birthday',
#    'happy birthday',
#    'happy birthday',
#    'happy birthday']},
#  {'image_id': 370270,
#   'question_id': '3hvf4MjtcgpFznUWS5bbvj',
#   'answer': '',
#   'direct_answers': ['baseball',
#    'baseball',
#    'baseball',
#    'baseball',
#    'baseball',
#    'baseball',
#    'baseball',
#    'baseball',
#    'baseball',
#    'baseball']},
#  {'image_id': 547816,
#   'question_id': '3qnvp3XRGpc5L6RMhRZ3gg',
#   'answer': 'room',
#   'direct_answers': ['shampoo',
#    'soap',
#    'shampoo',
#    'shampoo conditioner',
#    'shampoo',
#    'shampoo conditioner',
#    'shampoo',
#    'shampoo conditioner',
#    'shampoo',
#    'shampoo conditioner']},
#  {'image_id': 195842,
#   'question_id': '3vbWi2p7C9SSUHWSdbMYbE',
#   'answer': '',
#   'direct_answers': ['boxing',
#    'boxing',
#    'boxing',
#    'boxing',
#    'boxing',
#    'wii sports',
#    'boxing',
#    'wii',
#    'wii boxing',
#    'boxing']},
#  {'image_id': 485480,
#   'question_id': '3w3DT989GgT6yjqurjvmt6',
#   'answer': '',
#   'direct_answers': ['bunt',
#    'bunt',
#    'swing',
#    'bunt',
#    'bunt',
#    'bunt',
#    'hitting',
#    'bunt',
#    'swing',
#    'bunt']},
#  {'image_id': 156278,
#   'question_id': '3zxLUD8FPcCLJWYsG7h2KY',
#   'answer': '',
#   'direct_answers': ['home',
#    'domestic kitchen',
#    'kitchen',
#    'kitchen',
#    'kitchen',
#    'home',
#    'hostel',
#    'kitchen',
#    'kitchen',
#    'home kitchen']},
#  {'image_id': 286994,
#   'question_id': '455nQuaxbURN5ofLfbCqfq',
#   'answer': 'scape',
#   'direct_answers': ['savanna',
#    'rugged',
#    'grassy hilly',
#    'sandy',
#    'plains',
#    'safari',
#    'jungle',
#    'savannas',
#    'plains',
#    'savanna']},
#  {'image_id': 212559,
#   'question_id': '45ZJiwQ8E4sqUTyJSUzEN3',
#   'answer': '',
#   'direct_answers': ['metal',
#    'metal',
#    'metal',
#    'food tray',
#    'wood',
#    'steel',
#    'aluminum',
#    'metal',
#    'steel',
#    'metal']},
#  {'image_id': 463522,
#   'question_id': '49CisPCc2LiA5TUAdHZgXe',
#   'answer': '',
#   'direct_answers': ['dog',
#    'horse',
#    'dog',
#    'horse',
#    'dog',
#    'dog',
#    'dog',
#    'dog',
#    'dog',
#    'dog']},
#  {'image_id': 229358,
#   'question_id': '4BFN6MtJcaFzpccm3UwZva',
#   'answer': '',
#   'direct_answers': ['bathroom',
#    'bathroom',
#    'bathroom',
#    'bathroom',
#    'bathroom',
#    'bathroom',
#    'bathroom',
#    'bathroom',
#    'bathroom',
#    'bathroom']},
#  {'image_id': 127182,
#   'question_id': '4C2cZitDfGX5ytw6YTcxiL',
#   'answer': '',
#   'direct_answers': ['cupboard',
#    'sink',
#    'cupboard',
#    'sink',
#    'sink',
#    'sink',
#    'sink',
#    'cabinets',
#    'sink',
#    'sink']},
#  {'image_id': 153632,
#   'question_id': '4FBqxbmT4zCDwWzm3gH7LY',
#   'answer': 'knife is for the meat',
#   'direct_answers': ['plated',
#    'frogs',
#    'meat',
#    'meat',
#    "whatever's pictured",
#    'squid',
#    'meat',
#    'meat',
#    'crabs',
#    'mushrooms']},
#  {'image_id': 217285,
#   'question_id': '4H7KMfvPvCTSvtf8Uyp55D',
#   'answer': '',
#   'direct_answers': ['cooler',
#    'drinks',
#    'drinks',
#    'drinks',
#    'drinks',
#    'cooler',
#    'storage',
#    'cooler',
#    'cooler',
#    'drinks']},
#  {'image_id': 149375,
#   'question_id': '4HXTUJHey3SSzuoE66yHKi',
#   'answer': '',
#   'direct_answers': ['tie dye',
#    'tie dye',
#    'tie dye',
#    'tie dye',
#    'tie die',
#    'casual',
#    'tye dye',
#    'tie dyed',
#    'tie dye',
#    'tye die']},
#  {'image_id': 104612,
#   'question_id': '4PvLY9C3GyARH3WSGYbYFq',
#   'answer': '',
#   'direct_answers': ['asian',
#    'asian',
#    'asian cuisine',
#    'healthy',
#    'chicken lomein',
#    'chinese',
#    'stir fry',
#    'asian',
#    'salad',
#    'chinese']},
#  {'image_id': 502599,
#   'question_id': '4U4iSWxvXv9RtE6V9KpxJo',
#   'answer': 'plane',
#   'direct_answers': ['call letters',
#    'number',
#    'number',
#    'numbers',
#    'call numbers',
#    'big windows',
#    'orange planes',
#    'call sign',
#    'wing',
#    'identification number']},
#  {'image_id': 511999,
#   'question_id': '4UrYfZMUToiF5f7GK6eMaz',
#   'answer': '',
#   'direct_answers': ['safety',
#    'safety',
#    'safety reflection',
#    'safety',
#    'visibility',
#    'safety',
#    'workers',
#    'visibility',
#    'visibility',
#    'safety reflection']},
#  {'image_id': 242060,
#   'question_id': '4YvFMFoDw46kzXhajSgc9W',
#   'answer': "it's a table",
#   'direct_answers': ['eat',
#    'eat',
#    'tea party',
#    'eat cake',
#    'lunch',
#    'to eat',
#    'eat food',
#    'breakfast',
#    'food temptation',
#    'to eat']},
#  {'image_id': 383443,
#   'question_id': '4Z7WvuLTj7VUpVtLL2W2g7',
#   'answer': '',
#   'direct_answers': ['bathroom',
#    'bathroom',
#    'bathroom',
#    'bathroom',
#    'bathroom sinks',
#    'bathroom sinks',
#    'bathroom sinks',
#    'bathroom',
#    'ceramic',
#    'bathroom']},
#  {'image_id': 176799,
#   'question_id': '4cdYbJFFeKXJr6LbKgcxTa',
#   'answer': 'a skate park',
#   'direct_answers': ['urban',
#    'playing',
#    'skate park',
#    'urban',
#    'warm tropical',
#    'urban',
#    'tropical',
#    'business',
#    'city',
#    'urban areas']},
#  {'image_id': 287874,
#   'question_id': '4dnt6ahNTCENKrvBhExyvV',
#   'answer': '',
#   'direct_answers': ['absolutely no',
#    'no',
#    'no',
#    'no',
#    'yes',
#    'yes',
#    'yes',
#    'no',
#    'no',
#    'no']},
#  {'image_id': 521509,
#   'question_id': '4iV8UfNJs7Wy6XAt9SHMVJ',
#   'answer': '',
#   'direct_answers': ['bedroom',
#    'bedroom',
#    'bedroom',
#    'bedroom',
#    'bedroom',
#    'bedroom',
#    'bedroom',
#    'bedroom',
#    'bedroom',
#    'bedroom']},
#  {'image_id': 208363,
#   'question_id': '4j6bW4ChHncMKUnmnGAQQ2',
#   'answer': '',
#   'direct_answers': ['meeting',
#    'meeting',
#    'school event',
#    'meeting',
#    'party',
#    'working event',
#    'party',
#    'social',
#    'academic',
#    'party']},
#  {'image_id': 214192,
#   'question_id': '4jnshoBeGDGmRjspTuvr29',
#   'answer': 'cycle',
#   'direct_answers': ['motorcycle',
#    'motorcycles',
#    'dirt bikes',
#    'motorcycles',
#    'motorbikes',
#    'motorcycle',
#    'dirtbike',
#    'dirt bikes',
#    'motorcycles',
#    'dirt bikes']},
#  {'image_id': 338625,
#   'question_id': '4mgcpzD4d6adkPQP7cxg54',
#   'answer': 'York City',
#   'direct_answers': ['new york',
#    'new york',
#    'new york',
#    'new york',
#    'new york',
#    'new york',
#    'new york',
#    'nyc',
#    'new york',
#    'new york']},
#  {'image_id': 8844,
#   'question_id': '4t5DcDdFbw5x9PVRKis5AQ',
#   'answer': '',
#   'direct_answers': ['banana',
#    'shake',
#    'shake',
#    'juice',
#    'smoothie',
#    'fruit juice',
#    'smoothie',
#    'milkshake',
#    'smoothie',
#    'milkshake']},
#  {'image_id': 259830,
#   'question_id': '4wVv7CDVuQNaz7LLHDg89t',
#   'answer': '',
#   'direct_answers': ['two wheeler',
#    'bicycle parking',
#    'bike',
#    'bike',
#    'bicycle',
#    'bicycle',
#    'two wheeler',
#    'metered parking',
#    'outdoors',
#    'bike']},
#  {'image_id': 528578,
#   'question_id': '4xBq7ak8qCE92z8vddKXtu',
#   'answer': '',
#   'direct_answers': ['left side',
#    'left',
#    'north',
#    'left',
#    'west',
#    'left',
#    'left',
#    'left',
#    'sideways',
#    'windward']},
#  {'image_id': 456496,
#   'question_id': '4yd2xqYxWenwSYEucHnNXR',
#   'answer': 'is, france',
#   'direct_answers': ['paris',
#    'france',
#    'france',
#    'paris',
#    'france',
#    'france',
#    'france',
#    'france',
#    'france',
#    'france']},
#  {'image_id': 50896,
#   'question_id': '4yq3AnREQ4PP7MXMWvBb5a',
#   'answer': '',
#   'direct_answers': ['fall',
#    'christmas',
#    'fall',
#    'christmas',
#    'summer',
#    'fall',
#    'summer',
#    'christmas',
#    'fall',
#    'christmas']},
#  {'image_id': 82821,
#   'question_id': '5AhBQW2ucGSwJbPTtXHTFd',
#   'answer': 'oes',
#   'direct_answers': ['cars',
#    'cars',
#    'cars',
#    'cars',
#    'cars',
#    'cars',
#    'cars',
#    'cars',
#    'cars',
#    'cars']},
#  {'image_id': 548246,
#   'question_id': '5LTzpByXwsWGViYAXqiVEX',
#   'answer': '',
#   'direct_answers': ['balls',
#    'balls',
#    'tennis balls',
#    'ball',
#    'tennis balls',
#    'balls',
#    'tennis balls',
#    'tennis balls',
#    'balls',
#    'ball']},
#  {'image_id': 142790,
#   'question_id': '5NysKUokKJcrFfUcBbr9Vo',
#   'answer': '',
#   'direct_answers': ['wipeout',
#    'they fell',
#    'collusion',
#    'accident',
#    'people fell',
#    'collision',
#    'collision',
#    'crashing',
#    'accident',
#    'crashed']},
#  {'image_id': 27696,
#   'question_id': '5QURaRC8e3HjPpYC2GrX4u',
#   'answer': 'oni',
#   'direct_answers': ['mushrooms',
#    'cheese',
#    'mushroom',
#    'mushrooms',
#    'pepper',
#    'mushrooms',
#    'tomato',
#    'spice',
#    'mushroom',
#    'peppers']},
#  {'image_id': 528399,
#   'question_id': '5Re4MQxw5XwLbQQzqQVZcV',
#   'answer': '',
#   'direct_answers': ['vegetable',
#    'soup',
#    'soup',
#    'soup',
#    'spinach',
#    'salad',
#    'lettuce',
#    'soup',
#    'drinks',
#    'vegetables']},
#  {'image_id': 383289,
#   'question_id': '5S32A279iAfRetbkeWJd77',
#   'answer': 'a car"',
#   'direct_answers': ['scooter',
#    'silver',
#    'silver car',
#    'segway',
#    'two-wheeler',
#    'segway',
#    'scooter',
#    'gray car',
#    'scooter',
#    'segway']},
#  {'image_id': 433204,
#   'question_id': '5SgmGLJtR47rB539V4Jwt6',
#   'answer': 'are riding motorcycles',
#   'direct_answers': ['safety',
#    'safety',
#    'visibility',
#    'our culture',
#    'safety',
#    'safety',
#    'visibility',
#    'workers',
#    'working',
#    'safety']},
#  {'image_id': 419408,
#   'question_id': '5TbBvzzr5N35YUs7yBd7Ah',
#   'answer': 'bench',
#   'direct_answers': ['chain',
#    'rope',
#    'posts',
#    'rope',
#    'fence',
#    'chain',
#    'post',
#    'ropes',
#    'chain link',
#    'rope']},
#  {'image_id': 216497,
#   'question_id': '5XBmJitjSm9g7SQqNxYpe7',
#   'answer': '',
#   'direct_answers': ['sofa',
#    'island',
#    'island',
#    'island',
#    'island',
#    'table',
#    'kitchen island',
#    'microwave',
#    'table',
#    'island']},
#  {'image_id': 574702,
#   'question_id': '5Y5u3gnReRQbzkRnGw5ywd',
#   'answer': '',
#   'direct_answers': ['bricks',
#    'cobble stone',
#    'hexagons',
#    'brick',
#    'hexagons',
#    'stones',
#    'stone',
#    'cobblestone',
#    'bikes',
#    'stone']},
#  {'image_id': 86220,
#   'question_id': '5aRkxnYoakzDQFyDGb9qJ2',
#   'answer': '',
#   'direct_answers': ['green',
#    'jessica biel',
#    'eva green',
#    'green',
#    'eva green',
#    'eva',
#    'eva green',
#    'eva green',
#    'signal',
#    'michelle green']},
#  {'image_id': 277689,
#   'question_id': '5aXXZiPUcUzScs2do5tjYs',
#   'answer': '',
#   'direct_answers': ['roses',
#    'piping tip',
#    'elaborate frosting',
#    'bakery',
#    'carefully',
#    'icing',
#    'flowers',
#    'frosting roses',
#    'frosting',
#    'icing']},
#  {'image_id': 144932,
#   'question_id': '5cNGmGcUxJP7rwHnc6BXrs',
#   'answer': '',
#   'direct_answers': ['flotation',
#    'bathroom',
#    'restroom',
#    'restroom',
#    'bathroom',
#    'portapotty',
#    'toilet',
#    'outhouse',
#    'potty',
#    'shelter']},
#  {'image_id': 386352,
#   'question_id': '5fDUuYWCZMudfXVEPywFYc',
#   'answer': '',
#   'direct_answers': ['maria sharapova',
#    'paris hilton',
#    'sitting guy',
#    'skin',
#    'swedish persons',
#    'spectectors',
#    'no one',
#    'no one',
#    'blake lively',
#    'heidi klum']},
#  {'image_id': 286458,
#   'question_id': '5gQSkSh2eK3ZZ8bEyweBiA',
#   'answer': "it's a great bag for traveling",
#   'direct_answers': ['travel',
#    'safety',
#    'travel',
#    'trip',
#    'travel',
#    'traveling',
#    'carry samples',
#    'vacation',
#    'personal items',
#    'travelling']},
#  {'image_id': 99024,
#   'question_id': '5jGPL4u8JFHkLyQCG354uG',
#   'answer': 'kite',
#   'direct_answers': ['kite',
#    'kite',
#    'kite',
#    'kite',
#    'kite',
#    'kite',
#    'kite',
#    'kite',
#    'kite',
#    'kite']},
#  {'image_id': 271116,
#   'question_id': '5oBisjqVjcXEXGkd2uKPDe',
#   'answer': 'is looking at his cell phone',
#   'direct_answers': ['phone',
#    'phone',
#    'phone',
#    'cellphone',
#    'phone',
#    'cellphone',
#    'phone',
#    'phone',
#    'cellphone',
#    'phone']},
#  {'image_id': 34205,
#   'question_id': '5wfUGvXtyEw22kABjGaHxT',
#   'answer': 'ccoli',
#   'direct_answers': ['lemon juice',
#    'chicken',
#    'mushrooms',
#    'broccoli',
#    'mushrooms',
#    'pepper',
#    'parsley',
#    'mushroom',
#    'pepper',
#    'fish']},
#  {'image_id': 115245,
#   'question_id': '5z9Zmf4GRKoCa7igqv4Ef7',
#   'answer': '',
#   'direct_answers': ['travel',
#    'travel',
#    'parking',
#    'travelers clothes',
#    'traveling luggage',
#    'suitcase',
#    'travel',
#    'traveling',
#    'clothing',
#    'travel']},
#  {'image_id': 455157,
#   'question_id': '64o6jMUzFmawogFAYnhNoh',
#   'answer': '',
#   'direct_answers': ['camo',
#    'cammo',
#    'camouflage',
#    'camo',
#    'camo',
#    'camo',
#    'camouflage',
#    'cammo',
#    'camo',
#    'camo']},
#  {'image_id': 456496,
#   'question_id': '64yPpMFbTw3CnmTULYZWTp',
#   'answer': 'is',
#   'direct_answers': ['paris',
#    'paris',
#    'paris',
#    'paris',
#    'france',
#    'paris',
#    'france',
#    'paris',
#    'paris',
#    'paris']},
#  {'image_id': 205282,
#   'question_id': '65Sfsx6hqdJ5UqNWLB3RCG',
#   'answer': '',
#   'direct_answers': ['africa',
#    'african',
#    'wild',
#    'africa',
#    'field',
#    'forest',
#    'africa',
#    'jungle',
#    'savanna',
#    'africa']},
#  {'image_id': 472375,
#   'question_id': '66abRGQG535WgzgU5Ue9ru',
#   'answer': 'the living room',
#   'direct_answers': ['hallway',
#    'home',
#    'bedroom',
#    'street',
#    'garage',
#    'garage',
#    'livingroom',
#    'garage',
#    'garage',
#    'garage']},
#  {'image_id': 36494,
#   'question_id': '6EzruBdkEgwx74NmrhoyBV',
#   'answer': 'light',
#   'direct_answers': ['sunlight',
#    'clock',
#    'clock',
#    'clock',
#    'clock',
#    'clock',
#    'skylight',
#    'window',
#    'clock',
#    'clock window']},
#  {'image_id': 314182,
#   'question_id': '6FKSZrTS9wzHwnKasBSfdP',
#   'answer': '',
#   'direct_answers': ['sour cream',
#    'dip',
#    'dipping',
#    'dip',
#    'dipping',
#    'dipping',
#    'dip',
#    'dip',
#    'dipping',
#    'dipping']},
#  {'image_id': 258793,
#   'question_id': '6HizsyvwUgduwabP2dWha5',
#   'answer': 'buildings',
#   'direct_answers': ['sun',
#    'sun',
#    'sunlight',
#    'sun',
#    'sun',
#    'sunlight',
#    'sunlight',
#    'sun',
#    'sunlight',
#    'sun']},
#  {'image_id': 170099,
#   'question_id': '6J2yw53YiEDoNpMSt9mSsC',
#   'answer': 'audience is likely to be a business audience',
#   'direct_answers': ['coworkers',
#    'college students',
#    'designers',
#    'theater',
#    'office',
#    'art',
#    'women',
#    'business',
#    'meeting',
#    'stage']},
#  {'image_id': 577976,
#   'question_id': '6LfBvcynQvD7BaU3CCvfNG',
#   'answer': '',
#   'direct_answers': ['building',
#    'building',
#    'trafic rules',
#    'building',
#    'building',
#    'building',
#    'transportation depo',
#    'building',
#    'building',
#    'mall construction']},
#  {'image_id': 41872,
#   'question_id': '6Ps8BgA4pbvK4eKToCDQqu',
#   'answer': 'room',
#   'direct_answers': ['fireplace',
#    'fire',
#    'fireplace',
#    'fireplace',
#    'fireplace',
#    'fireplace',
#    'fireplace',
#    'fire',
#    'fire',
#    'fireplace']},
#  {'image_id': 511321,
#   'question_id': '6Qf2MxVMdHGnxrEZ3xGn7Q',
#   'answer': '',
#   'direct_answers': ['bridge',
#    'seasickness',
#    'rain',
#    'storm',
#    'collision',
#    'bridge',
#    'storm',
#    'hit bridge',
#    'raining',
#    'bad weather']},
#  {'image_id': 137576,
#   'question_id': '6QuPF6pNBjs3DEXQh4AQt4',
#   'answer': '',
#   'direct_answers': ['eating',
#    'to eat',
#    'grazing',
#    'feeding',
#    'eating hay',
#    'eating',
#    'eating hay',
#    'eating hay',
#    'eating',
#    'food']},
#  {'image_id': 293245,
#   'question_id': '6SYTPwk8BEHMp486oLsFgw',
#   'answer': '',
#   'direct_answers': ['new york',
#    'new york',
#    'new york',
#    'new york',
#    'new york',
#    'new york',
#    'new york',
#    'new york',
#    'new york',
#    'new york']},
#  {'image_id': 516601,
#   'question_id': '6YyPKdGwhA3LJkUpL3p9F6',
#   'answer': 'ing',
#   'direct_answers': ['skiing',
#    'skating',
#    'skiing',
#    'skiing',
#    'skiing',
#    'skiing',
#    'skiing',
#    'skiing',
#    'skiing',
#    'skiing']},
#  {'image_id': 100624,
#   'question_id': '6bXnCzchqyDdBZcBGGNbmm',
#   'answer': 'district',
#   'direct_answers': ['downtown',
#    'downtown',
#    'commercial',
#    'shopping',
#    'urban',
#    'urban',
#    'shopping',
#    'commercial',
#    'hipster commercial',
#    'shopping']},
#  {'image_id': 434548,
#   'question_id': '6fCWweqmigW6UaiyaHq4Sy',
#   'answer': '',
#   'direct_answers': ['pitcher',
#    'baseball player',
#    'baseball',
#    'pitcher',
#    'pitcher',
#    'pitcher',
#    'position',
#    'pitcher',
#    'pitcher',
#    'pitcher']},
#  {'image_id': 77396,
#   'question_id': '6kgVidVJRysLz6Rx3eNBZi',
#   'answer': 'the living room',
#   'direct_answers': ['living room',
#    'home',
#    'carpet',
#    'living room',
#    'living room',
#    'living room',
#    'home',
#    'living room',
#    'livingroom',
#    'floor']},
#  {'image_id': 314251,
#   'question_id': '6kpEuXnXz4ghWMLLBcRjmf',
#   'answer': '',
#   'direct_answers': ['passing',
#    'no idea',
#    'stop',
#    'parking',
#    'proceeding',
#    'crossing',
#    'parking',
#    'parking',
#    'driving',
#    'no idea']},
#  {'image_id': 446522,
#   'question_id': '6kv3CWDoRDsm2DnUCHRgmk',
#   'answer': 'a chair',
#   'direct_answers': ['chair',
#    'chair',
#    'chair',
#    'chair',
#    'couch',
#    'home',
#    'chair',
#    'chair',
#    'chair',
#    'chair']},
#  {'image_id': 6771,
#   'question_id': '6nV6KKMbWYsw8Rv9Sw7k2N',
#   'answer': 'Camelot"',
#   'direct_answers': ['cleopatra',
#    'masquerade participant',
#    'xena',
#    'zena',
#    'viking',
#    'cleopatra',
#    'xena',
#    'queen',
#    'zena',
#    'queen']},
#  {'image_id': 560474,
#   'question_id': '6ony7mfRzE7tEhj5udEe5u',
#   'answer': 'show',
#   'direct_answers': ['contest',
#    'festival',
#    'parade',
#    'dentist event',
#    'toothpaste event',
#    'dental convention',
#    'art show',
#    'art show',
#    'festival',
#    'parade']},
#  {'image_id': 23126,
#   'question_id': '6pLYuYn5suAGgoBgJ4Z6HC',
#   'answer': 'a horse',
#   'direct_answers': ['riding horse',
#    'roman riding',
#    'balance',
#    'riding',
#    'horseback riding',
#    'horse riding',
#    'show performance',
#    'riding horses',
#    'horseback riding',
#    'riding']},
#  {'image_id': 579970,
#   'question_id': '6pTSACKywJKkVRa7WGmzKe',
#   'answer': '',
#   'direct_answers': ['green',
#    'green',
#    'green',
#    'green',
#    'grey/green',
#    'green',
#    'green',
#    'dark green',
#    'green',
#    'grey']},
#  {'image_id': 87144,
#   'question_id': '6phsfhJ9iw5j6nYTpVBd9A',
#   'answer': '',
#   'direct_answers': ['mother/child',
#    'parents',
#    'parents',
#    'parents',
#    'mother/child',
#    'parents',
#    'parents',
#    'grandparents',
#    'parents',
#    'parents']},
#  {'image_id': 117719,
#   'question_id': '6vnibNuMQyy5nWAxNEGTgj',
#   'answer': '',
#   'direct_answers': ['alcohol',
#    'alcohol',
#    'alcohol',
#    'liquour',
#    'alcohol',
#    'alcohol',
#    'alcoholic drinks',
#    'cocktails',
#    'alcohol',
#    'alcohol']},
#  {'image_id': 274460,
#   'question_id': '6xTMCHe4ABbm6NDntoEkLJ',
#   'answer': '',
#   'direct_answers': ['palm tree',
#    'palm tree',
#    'palm',
#    'palm',
#    'palm',
#    'palm tree',
#    'palm tree',
#    'palm',
#    'palm tree',
#    'palm tree']},
#  {'image_id': 553221,
#   'question_id': '73ixwXaUcqfgsJYLzCABWC',
#   'answer': 'ite',
#   'direct_answers': ['kite',
#    'parasail',
#    'wind',
#    'parasail',
#    'wind',
#    'handle',
#    'sail',
#    'boat engine',
#    'parachute',
#    'kite']},
#  {'image_id': 259640,
#   'question_id': '73kd5sUo4zXkApi6v4X8Qc',
#   'answer': 'os',
#   'direct_answers': ['mexican',
#    'tamales',
#    'mexican',
#    'mexican',
#    'mexican',
#    'mexican',
#    'mexican',
#    'tacos',
#    'mexican',
#    'tamales']},
#  {'image_id': 88462,
#   'question_id': '74CMNF7KTeAFsXza5GJLGb',
#   'answer': 'bus',
#   'direct_answers': ['school bus',
#    'school bus',
#    'school',
#    'school bus',
#    'school',
#    'school bus',
#    'school',
#    'school',
#    'school',
#    'school bus']},
#  {'image_id': 113589,
#   'question_id': '764XKetFB6T3wsiABqc79e',
#   'answer': 'the shape of a triangle',
#   'direct_answers': ['triangle',
#    'triangle',
#    'triangle',
#    'triangles',
#    'triangle',
#    'triangles',
#    'triangles',
#    'triangles',
#    'triangle',
#    'triangle']},
#  {'image_id': 148957,
#   'question_id': '767TWXi3wYjFiBX3YXyMuU',
#   'answer': 'aze',
#   'direct_answers': ['frosting',
#    'chocolate',
#    'icing',
#    'chocolate',
#    'icing',
#    'paint',
#    'sugar glaze',
#    'frosting',
#    'icing',
#    'frosting']},
#  {'image_id': 151000,
#   'question_id': '79yRxKFXwWZZiCBAHtJqeE',
#   'answer': '20th century',
#   'direct_answers': ['twentieth',
#    '20th',
#    '1900s',
#    'twenty-first',
#    'twentieth century',
#    '20th century',
#    'twenty first',
#    '19',
#    'twentieth',
#    'twentieth']},
#  {'image_id': 195918,
#   'question_id': '7CWwGUgRqbPEiGcZEzFVEF',
#   'answer': '',
#   'direct_answers': ['feline',
#    'cat',
#    'leopard',
#    'feline',
#    'panthera',
#    'cat',
#    'panthera',
#    'panthera',
#    'panthera',
#    'leopard']},
#  {'image_id': 148719,
#   'question_id': '7CrtnvrK5CTs6c9RC8WgPB',
#   'answer': '',
#   'direct_answers': ['dodge',
#    'dodge',
#    'dodge',
#    'dodge',
#    'dodge',
#    'dodge',
#    'dodge',
#    'dodge',
#    'dodge',
#    'dodge']},
#  {'image_id': 313783,
#   'question_id': '7DWnTRkU9e86XMwb7QqxYd',
#   'answer': 'illed',
#   'direct_answers': ['grilling',
#    'grill',
#    'grilling',
#    'grilling',
#    'grill',
#    'grilling',
#    'grilling',
#    'grilled',
#    'grilling boiling',
#    'grilling']},
#  {'image_id': 403817,
#   'question_id': '7Hndh7JzZ7BizC4XDSV5Z5',
#   'answer': '',
#   'direct_answers': ['calico',
#    'domestic',
#    'house cat',
#    'domestic shorthair',
#    'domestic shorthair',
#    'housecat',
#    'tuxedo cat',
#    'piebald',
#    'tuxedo',
#    'house cat']},
#  {'image_id': 169996,
#   'question_id': '7KNmiZTYRQBHMJKJ9zkAjR',
#   'answer': 'speed limit',
#   'direct_answers': ['stop light',
#    'brakes',
#    'red light',
#    'red light',
#    'traffic lights',
#    'traffic lights',
#    'stoplight',
#    'brakes',
#    'signage',
#    'traffic']},
#  {'image_id': 68933,
#   'question_id': '7L2zGA6XFJrPCfLJCwBrww',
#   'answer': '',
#   'direct_answers': ['grazing',
#    'grazing',
#    'eating',
#    'eating',
#    'eating',
#    'grazing',
#    'eating',
#    'grazing',
#    'grazing',
#    'eating']},
#  {'image_id': 549390,
#   'question_id': '7NXz8t4QzQWvJzpHqfPzRw',
#   'answer': 'they are there',
#   'direct_answers': ['spectators',
#    'audience',
#    'spectators',
#    "they're riding",
#    'spectating',
#    'spectators',
#    'spectators',
#    'spectators',
#    'spectators',
#    'observing']},
#  {'image_id': 423506,
#   'question_id': '7NbKNXQWBYJ8HTRo2J8CoU',
#   'answer': 'green shirt',
#   'direct_answers': ['vest',
#    'sweater',
#    'vneck sweater',
#    'vest',
#    'grey sweater',
#    'vest',
#    'sweater',
#    'vest',
#    'lanyard',
#    'sweater']},
#  {'image_id': 132375,
#   'question_id': '7NxakvvZZEHKsh8MbNHHvz',
#   'answer': '',
#   'direct_answers': ['jar',
#    'canning jar',
#    'glass jar',
#    'mason jar',
#    'glass',
#    'canning jar',
#    'jar',
#    'mason jar',
#    'mason jar',
#    'ball jar']},
#  {'image_id': 493799,
#   'question_id': '7RjA6a3CFR8w5fVRc8Arji',
#   'answer': 'arian',
#   'direct_answers': ['low calorie',
#    'vegetarian',
#    'vegetarian',
#    'vegetarian',
#    'healthy diet',
#    'vegetarian',
#    'keto',
#    'atkins',
#    'vegetarian',
#    'vegetarian']},
#  {'image_id': 378515,
#   'question_id': '7ViVwUt2pnJxqcZoeTc4TR',
#   'answer': '',
#   'direct_answers': ['banana',
#    'bananas',
#    'bananas',
#    'bananas',
#    'banana',
#    'bananas',
#    'bananas',
#    'banana',
#    'bananas',
#    'bananas']},
#  {'image_id': 463527,
#   'question_id': '7VodQFaYKxhUwQ5tpFSkRo',
#   'answer': 'drink',
#   'direct_answers': ['liquor',
#    'baileys',
#    'liqueur',
#    'alcohol',
#    'coffee liquor',
#    'salt pepper',
#    'alcohol',
#    'alcohol',
#    "bailey's liqueur",
#    'liquer']},
#  {'image_id': 434297,
#   'question_id': '7Wj97TEQc4fnsxvvsbnUXH',
#   'answer': '',
#   'direct_answers': ['carrot',
#    'carrot',
#    'carrot',
#    'chicken',
#    'carrot',
#    'carrot',
#    'carrot',
#    'carrot',
#    'carrot',
#    'carrots']},
#  {'image_id': 16228,
#   'question_id': '7YTajnBGjXEmwuYjmsXsdX',
#   'answer': '',
#   'direct_answers': ['disneyland',
#    'amusement park',
#    'disneyland',
#    'disneyland',
#    'disney',
#    'magic castle',
#    'disneyland',
#    'disneyland',
#    'disneyland',
#    'disneyland']},
#  {'image_id': 368900,
#   'question_id': '7ZA9sk8eRjBsisqK4EgQM2',
#   'answer': 'TV',
#   'direct_answers': ['woman',
#    'profile',
#    'woman',
#    'picture',
#    'woman',
#    'tube',
#    'person',
#    'person',
#    'face',
#    'woman']},
#  {'image_id': 79229,
#   'question_id': '7dxcZiZowsAK34QswVhXy3',
#   'answer': '10',
#   'direct_answers': ['cold',
#    'cold',
#    'cold',
#    'cool range',
#    'temperate',
#    'cold',
#    'cold',
#    'chilly',
#    'hot',
#    'chilly']},
#  {'image_id': 442480,
#   'question_id': '7hKGdKpiEqfqB8dEeAw9hu',
#   'answer': '',
#   'direct_answers': ['rainy',
#    'rain',
#    'rainy',
#    'rain',
#    'rain',
#    'raining',
#    'rain',
#    'rainy',
#    'rain',
#    'rain']},
#  {'image_id': 514508,
#   'question_id': '7jkWRB4pt8ZordP6wDAvbT',
#   'answer': '',
#   'direct_answers': ['first meeting',
#    'microwave',
#    'relationship',
#    'television',
#    'talk show',
#    'television',
#    'tv show',
#    'tv',
#    'television',
#    'television']},
#  {'image_id': 195754,
#   'question_id': '7pAKkw446jdqTk9peDKjyY',
#   'answer': 'room',
#   'direct_answers': ['basement',
#    'basement',
#    'basement',
#    'basement',
#    'basement',
#    'first',
#    'first',
#    'basement',
#    'basement',
#    'basement']},
#  {'image_id': 315001,
#   'question_id': '7xotSD89TZKNHK4rMZLzfo',
#   'answer': '',
#   'direct_answers': ['seagulls',
#    'seagulls',
#    'seagulls',
#    'seagulls',
#    'seagulls',
#    'aquatic',
#    'seagulls',
#    'seagulls',
#    'seagulls',
#    'seagulls']},
#  {'image_id': 495054,
#   'question_id': '82bLyanbdDeEq6mkVa3YGM',
#   'answer': 'States',
#   'direct_answers': ['virgin atlantic',
#    'great britain',
#    'united kingdom',
#    'england',
#    'uk',
#    'usa',
#    'united kingdom',
#    'england',
#    'britain',
#    'america']},
#  {'image_id': 112298,
#   'question_id': '859iiHHEi5eRJHipVattDU',
#   'answer': 'pong',
#   'direct_answers': ['tennis',
#    'tennis',
#    'tennis',
#    'racket ball',
#    'tennis',
#    'tennis',
#    'tennis',
#    'racket ball',
#    'tennis',
#    'tennis']},
#  {'image_id': 457559,
#   'question_id': '86vHZcPAsgzHoG4VL93xqr',
#   'answer': 'team on offense',
#   'direct_answers': ['lime',
#    'red',
#    'lime',
#    'blue team',
#    'red',
#    'red',
#    'red',
#    'blue team',
#    'red',
#    'blue team']},
#  {'image_id': 510329,
#   'question_id': '87sGM3r7nnhwncMAKMtbuo',
#   'answer': 'object should never get wet',
#   'direct_answers': ['laptop',
#    'laptop',
#    'under rock',
#    'laptop computer',
#    'laptop',
#    'umbrella',
#    'electronics',
#    'cloth',
#    'laptop',
#    'laptop phone']},
#  {'image_id': 346905,
#   'question_id': '8HQ9sy9TdK4XZffkkhmtRW',
#   'answer': '',
#   'direct_answers': ['tail',
#    'tusks',
#    'tusk',
#    'tusks',
#    'tusks',
#    'tusks',
#    'tusks',
#    'tusks',
#    'arrow',
#    'tusks']},
#  {'image_id': 448410,
#   'question_id': '8KFq64eMdw4qeAp2JXe96r',
#   'answer': 'room',
#   'direct_answers': ['waiting room',
#    'train depot',
#    'waiting room',
#    'restroom',
#    'waiting room',
#    'resting',
#    'waiting room',
#    'waiting',
#    'station depot',
#    'waiting room']},
#  {'image_id': 226802,
#   'question_id': '8KqQoveNzvvZSgxxPeepUY',
#   'answer': '',
#   'direct_answers': ['bus',
#    'bus',
#    'bus',
#    'bus',
#    'bus',
#    'bus',
#    'bus',
#    'bus',
#    'red bus',
#    'bus']},
#  {'image_id': 84752,
#   'question_id': '8LVHUcGX7daYbXPh59c8pW',
#   'answer': '',
#   'direct_answers': ['military plane',
#    'jet',
#    'plane',
#    'plane',
#    'fighter jet',
#    'plane',
#    'airplane',
#    'airplane',
#    'airplane',
#    'plane']},
#  {'image_id': 180296,
#   'question_id': '8MMdCgrej5iBZ7PitRYrt3',
#   'answer': '',
#   'direct_answers': ['suitcase',
#    'suitcase',
#    'suitcase',
#    'roll away',
#    'suitcase',
#    'doll bag',
#    'backpack',
#    'suitcase',
#    'suitcase',
#    'suitcase']},
#  {'image_id': 330790,
#   'question_id': '8MrFkkmRAk7E8ccS8FPZ8S',
#   'answer': '',
#   'direct_answers': ['transportation',
#    'transport people',
#    'carry things',
#    'for riding',
#    'carry things',
#    'ride',
#    'carrying',
#    'for riding',
#    'to ride',
#    'seat passengers']},
#  {'image_id': 458109,
#   'question_id': '8PZriuWuwokXCriqVBZwSJ',
#   'answer': '',
#   'direct_answers': ['track',
#    'train',
#    'tracks',
#    'tracks',
#    'train tracks',
#    'rails',
#    'train tracks',
#    'rails',
#    'tracks',
#    'rails']},
#  {'image_id': 403565,
#   'question_id': '8Q69Bei8UReA69MSuQAcLT',
#   'answer': 'bicycle',
#   'direct_answers': ['bike',
#    'picture',
#    'picture',
#    'picture',
#    'photographs',
#    'photograph',
#    'picture',
#    'picture',
#    'picture',
#    'picture']},
#  {'image_id': 36936,
#   'question_id': '8Qivn8LXSmWYmn7zgKGiw4',
#   'answer': '',
#   'direct_answers': ['drawer',
#    'speakers',
#    'speakers',
#    'speakers',
#    'speaker',
#    'speakers',
#    'speakers',
#    'speaker',
#    'speakers',
#    'stereo']},
#  {'image_id': 514376,
#   'question_id': '8R6BwQYURjKQu4FPYr8TpL',
#   'answer': ', WA',
#   'direct_answers': ['seattle',
#    'westlake',
#    'seattle',
#    'westlake',
#    'seattle',
#    'seattle',
#    'seattle',
#    'westlake',
#    'seattle',
#    'seattle']},
#  {'image_id': 512929,
#   'question_id': '8RDETmscMEEsHh6Sbekaa6',
#   'answer': '',
#   'direct_answers': ['smile',
#    'smile',
#    'joy',
#    'smiling',
#    'happy',
#    'smiles',
#    'smiling',
#    'happy',
#    'smiles',
#    'smiles']},
#  {'image_id': 556000,
#   'question_id': '8SzR5UpGtrsFWoxheZ9SkE',
#   'answer': 'Wii',
#   'direct_answers': ['wii',
#    'wii',
#    'wii',
#    'wii',
#    'wii',
#    'wii',
#    'wii',
#    'nintendo wii',
#    'wii',
#    'wii']},
#  {'image_id': 34139,
#   'question_id': '8dWqzZJR3MvHHSGAAzAEJy',
#   'answer': 'idelity is a financial services company',
#   'direct_answers': ['investments',
#    'investments',
#    'investments',
#    'investments',
#    'investments',
#    'investment',
#    'car',
#    'investing',
#    'investments',
#    'financial services']},
#  {'image_id': 567898,
#   'question_id': '8enBCTrMj57db8JVq9wyPq',
#   'answer': '',
#   'direct_answers': ['oranges',
#    'orange',
#    'orange flowers',
#    'orange slices',
#    'cantaloupe',
#    'oranges',
#    'orange',
#    'orange slices',
#    'orange',
#    'oranges']},
#  {'image_id': 172595,
#   'question_id': '8k5Wnk4jb9ZzTN8EHrqNS3',
#   'answer': 'computer',
#   'direct_answers': ['tissues',
#    'tissue',
#    'tissues',
#    'tissues',
#    'tissues',
#    'tissue',
#    'tissue',
#    'tissues',
#    'tissue',
#    'tissues']},
#  {'image_id': 210030,
#   'question_id': '8pfeZwe43HT9mMjVmdZhzm',
#   'answer': '',
#   'direct_answers': ['four',
#    'four',
#    'one',
#    'four',
#    'one',
#    'four',
#    'four',
#    'one',
#    'four',
#    'one']},
#  {'image_id': 378453,
#   'question_id': '8qqTsLQFXdEDT9oeVgZekp',
#   'answer': 'bras',
#   'direct_answers': ['water',
#    'muddy water',
#    'puddle',
#    'muddy puddle',
#    'water pool',
#    'water',
#    'water',
#    'mud',
#    'mud',
#    'puddle']},
#  {'image_id': 384468,
#   'question_id': '8spFMseWd5TyYXt4LygCE5',
#   'answer': '',
#   'direct_answers': ['one',
#    'one',
#    'one',
#    'one',
#    'one',
#    'one',
#    'one',
#    'one',
#    'one',
#    'one']},
#  {'image_id': 132931,
#   'question_id': '8tjSG5kCpUsF7QaQsPoJcG',
#   'answer': 'a',
#   'direct_answers': ['oma',
#    'omaha',
#    'heartland',
#    'omaha',
#    'omaha',
#    'omaha',
#    'omaha',
#    'omaha',
#    'omaha',
#    'omaha']},
#  {'image_id': 228942,
#   'question_id': '8uQHFZsgJwvQPuvYs7reMA',
#   'answer': '',
#   'direct_answers': ['stopping',
#    'stopping',
#    'driving',
#    'moving',
#    'driving',
#    'stopping',
#    'stopping',
#    'turning left',
#    'stopping',
#    'travel']},
#  {'image_id': 185472,
#   'question_id': '8vnLAkEcA5mAC66h59f4dE',
#   'answer': '',
#   'direct_answers': ['yes',
#    'yes',
#    'not yet',
#    'absolutely no',
#    'not yet',
#    'yes',
#    'not yet',
#    'yes',
#    'yes',
#    'yes']},
#  {'image_id': 162035,
#   'question_id': '8vuMQFQGMNiU6TcoNUNe2U',
#   'answer': 'rooms',
#   'direct_answers': ['advertisement',
#    'advertising',
#    'advertisement',
#    'advertisement',
#    'advertisement',
#    'advertisement',
#    'advertisement',
#    'advertise',
#    'advertisement',
#    'advertisement']},
#  {'image_id': 201646,
#   'question_id': '8vzpRWS6dDNrFCouzebMm9',
#   'answer': 'Wii',
#   'direct_answers': ['nintendo wii',
#    'wii',
#    'wii',
#    'wii',
#    'wii',
#    'wii',
#    'wii',
#    'wii',
#    'wii',
#    'wii']},
#  {'image_id': 15517,
#   'question_id': '8w7GuH4PjCommJcwHaGge6',
#   'answer': '',
#   'direct_answers': ['factory',
#    'asia',
#    'plant manufacturer',
#    'asia',
#    'japan',
#    'bus station',
#    'detroit',
#    'unknown',
#    'china',
#    'terminal']},
#  {'image_id': 177213,
#   'question_id': '8xMtKKAZ5RHWjwMgCuYjWV',
#   'answer': '',
#   'direct_answers': ['margherita',
#    'cheese',
#    'margarita',
#    'margherita',
#    'cheese',
#    'cheese',
#    'cheese',
#    'cheese',
#    'cheese',
#    'cheese']},
#  {'image_id': 87476,
#   'question_id': '92HRqF8nimMzat2iydhLAj',
#   'answer': 'is learning to ride a skateboard',
#   'direct_answers': ['practicing',
#    'learning balance',
#    'learning',
#    'riding',
#    'skating',
#    'skateboarding',
#    'riding',
#    'skateboarding',
#    'practicing skateboarding',
#    'skateboarding']},
#  {'image_id': 267434,
#   'question_id': '93rpK9LLNQ8xmAPrEGm3rv',
#   'answer': '',
#   'direct_answers': ['brick',
#    'bricks',
#    'stone',
#    'stone',
#    'stones',
#    'stone',
#    'stone',
#    'bricks',
#    'bricks',
#    'stone']},
#  {'image_id': 488664,
#   'question_id': '99Ra8z27K9FLU2u5acKAqp',
#   'answer': '',
#   'direct_answers': ['train',
#    'train',
#    'train',
#    'train',
#    'train',
#    'train',
#    'train',
#    'train',
#    'train',
#    'rail']},
#  {'image_id': 530061,
#   'question_id': '99VEZ5bvSGBLWtkpJiAAXg',
#   'answer': '',
#   'direct_answers': ['eating',
#    'eating',
#    'eating',
#    'eating',
#    'eating',
#    'eating',
#    'eating',
#    'eating',
#    'eating',
#    'eating']},
#  {'image_id': 243867,
#   'question_id': '9Fvp6un9Bh9va6z5nz9k74',
#   'answer': 'lot',
#   'direct_answers': ['urban',
#    'street',
#    'city',
#    'highway',
#    'shopping area',
#    'city',
#    'city street',
#    'commercial',
#    'city street',
#    'road']},
#  {'image_id': 382696,
#   'question_id': '9HoQP5bpke2rstGjD8AG7Y',
#   'answer': '',
#   'direct_answers': ['stove/oven',
#    'stove',
#    'washing machine',
#    'stove',
#    'stove',
#    'stove',
#    'washing machine',
#    'stove',
#    'oven',
#    'stove']},
#  {'image_id': 561889,
#   'question_id': '9J5n2f4j4R4B9t3c6MPSi3',
#   'answer': '',
#   'direct_answers': ['chicken',
#    'chicken',
#    'chicken',
#    'chicken',
#    'chicken',
#    'turkey',
#    'chicken',
#    'chicken',
#    'turkey',
#    'chicken']},
#  {'image_id': 459396,
#   'question_id': '9KA8dr22Hiveh2s9JwvPLZ',
#   'answer': 'head',
#   'direct_answers': ['ear',
#    'ear',
#    'ear',
#    'ear',
#    'tag',
#    'ear',
#    'ear',
#    'ear',
#    'tag',
#    'ear']},
#  {'image_id': 134112,
#   'question_id': '9PGPr3vxBAb9jyWDiR9ous',
#   'answer': 'illon',
#   'direct_answers': ['hp',
#    'hp',
#    'hp',
#    'hp',
#    'hewlett packard',
#    'hp',
#    'hewlett packard',
#    'hp',
#    'hewitt packard',
#    'hp']},
#  {'image_id': 174123,
#   'question_id': '9PZxoQZCdEn8VijhqTfENe',
#   'answer': 'fork',
#   'direct_answers': ['fork',
#    'fork',
#    'knife fork',
#    'fork',
#    'fork',
#    'knife fork',
#    'fork',
#    'fork',
#    'fork',
#    'fork']},
#  {'image_id': 82085,
#   'question_id': '9R6ddmMNiye654hqqPZ2eE',
#   'answer': '',
#   'direct_answers': ['prevent fire',
#    'guidance',
#    'barrier',
#    'border',
#    'walking on',
#    'train tracks',
#    'barrier',
#    'usa',
#    'decoration',
#    'border']},
#  {'image_id': 13923,
#   'question_id': '9R9Ef5J6eaJzSHvUEkBkgq',
#   'answer': '',
#   'direct_answers': ['cat',
#    'cardinal',
#    'rooster',
#    'rooster',
#    'panda',
#    'cardinal',
#    'bird',
#    'robin',
#    'cardinal',
#    'fox']},
#  {'image_id': 407083,
#   'question_id': '9TJtRYnGa8xr8CF67M5Mof',
#   'answer': '',
#   'direct_answers': ['cat',
#    'cat',
#    'cats',
#    'cats',
#    'cats',
#    'cat',
#    'cat',
#    'cat',
#    'cat',
#    'cat']},
#  {'image_id': 338560,
#   'question_id': '9TbmZ3Qq4paDv4AUeXpLEm',
#   'answer': 'fire hydrant',
#   'direct_answers': ['paint',
#    'dripping paint',
#    'paint',
#    'paint',
#    'paint',
#    'paint',
#    'dripping paint',
#    'dripping paint',
#    'paint',
#    'paint']},
#  {'image_id': 389381,
#   'question_id': '9VR7RNoJkVj6AWsYtwpDz7',
#   'answer': 'person who likes to eat healthy food',
#   'direct_answers': ['vegetarian',
#    'vegetarian',
#    'japanese',
#    'vegetarian',
#    'vegetarian',
#    'vegan',
#    'vegetarian',
#    'vegetarian',
#    'nutritionist',
#    'healthy']},
#  {'image_id': 420916,
#   'question_id': '9Vcrsyxf2zbSBauWavQbju',
#   'answer': 'person sitting on the bench',
#   'direct_answers': ['outsiders',
#    'middle',
#    'guy w/t-shirt',
#    'leftmost',
#    'middle person',
#    'all',
#    'middle',
#    'short sleeves',
#    'man',
#    'left']},
#  {'image_id': 349860,
#   'question_id': '9WmbdtPjrRDvD7yeHYr55d',
#   'answer': '',
#   'direct_answers': ['n pattern',
#    'letters',
#    'zigzag',
#    'outline pattern',
#    'lettering',
#    'polka dots',
#    'letters',
#    'graffiti',
#    'zero',
#    'letters']},
#  {'image_id': 276285,
#   'question_id': '9ZB4WcL9Sbo3L6ZPkaqzKY',
#   'answer': '',
#   'direct_answers': ['four',
#    'one',
#    'one',
#    'four',
#    'four',
#    'three',
#    'three',
#    'one',
#    'three',
#    'four']},
#  {'image_id': 223182,
#   'question_id': '9agpK8NJBKhb2vcWiKXRi7',
#   'answer': '',
#   'direct_answers': ['water',
#    'water',
#    'water',
#    'water',
#    'water',
#    'water',
#    'water',
#    'water',
#    'water',
#    'water']},
#  {'image_id': 2299,
#   'question_id': '9d7StqUZPtRBbHjSDFwwqa',
#   'answer': 'children are from the same school',
#   'direct_answers': ['school class',
#    'classmates',
#    'classmates',
#    'classmates',
#    'classmates',
#    'classmates',
#    'classmates',
#    'school chums',
#    'school',
#    'classmates']},
#  {'image_id': 365521,
#   'question_id': '9fX9oZHdEtHPfWbHi4BhwA',
#   'answer': '',
#   'direct_answers': ['tonic water',
#    'vodka',
#    'coke',
#    'coke',
#    'vodka',
#    'juice',
#    'orange juice',
#    'orange juice',
#    'coke',
#    'orange juice']},
#  {'image_id': 284725,
#   'question_id': '9m5dBgT3PJrhWRCDg9ee2z',
#   'answer': '',
#   'direct_answers': ['bus',
#    'bus',
#    'bus',
#    'bus',
#    'bus',
#    'bus',
#    'bus',
#    'passenger',
#    'bus',
#    'bus']},
#  {'image_id': 579070,
#   'question_id': '9mBjXaxYD4jzJptHzwbeYW',
#   'answer': '',
#   'direct_answers': ['paper',
#    'paper',
#    'paper',
#    'paper',
#    'plastic',
#    'paper',
#    'plastic',
#    'plastic',
#    'paper',
#    'paper']},
#  {'image_id': 369310,
#   'question_id': '9sqHw3RioVzmBGcxbMqBDM',
#   'answer': '',
#   'direct_answers': ['brown',
#    'brown',
#    'tan',
#    'brown',
#    'brown',
#    'brown',
#    'brown',
#    'brown',
#    'brown',
#    'brown']},
#  {'image_id': 53994,
#   'question_id': '9v2zVc4N5db5pVtYvrVEeD',
#   'answer': '',
#   'direct_answers': ['coins',
#    'change',
#    'change',
#    'money',
#    'change',
#    'coins',
#    'coins',
#    'money',
#    'coins',
#    'coins']},
#  {'image_id': 66841,
#   'question_id': '9wkHkHDXGGtbJwvLAcXSVs',
#   'answer': 'aster',
#   'direct_answers': ['toaster',
#    'toaster',
#    'toaster',
#    'toaster',
#    'toaster',
#    'putting utensil',
#    'toaster',
#    'toaster',
#    'toaster',
#    'toaster']},
#  {'image_id': 20571,
#   'question_id': '9zfgVSEG4hrKHfuoe4tHqx',
#   'answer': '',
#   'direct_answers': ['holding hands',
#    'talking',
#    'talking',
#    'being transported',
#    'view',
#    'viewing scenery',
#    'fishing',
#    'their boat',
#    'spend time',
#    'fishing']},
#  {'image_id': 236599,
#   'question_id': 'A2uU9gQWJp8Z3LJePdL9u8',
#   'answer': 'imono',
#   'direct_answers': ['kimono',
#    'dress',
#    'kimonos',
#    'dresses',
#    'dress',
#    'japanese',
#    'japanese',
#    'kimono',
#    'japanese',
#    'chinese robes']},
#  {'image_id': 508602,
#   'question_id': 'A2yJNQmbyDNtQEq4b2EZWx',
#   'answer': '',
#   'direct_answers': ['flew',
#    'landing',
#    'flying',
#    'flew',
#    'flying',
#    'flew',
#    'flying',
#    'flew',
#    'flew',
#    'flew']},
#  {'image_id': 2431,
#   'question_id': 'A3zGJC9ryU4EkHzywEGdJn',
#   'answer': 'glass of wine',
#   'direct_answers': ['drink',
#    'wine',
#    'wine',
#    'spoon',
#    'wine',
#    'wine',
#    'bruschetta',
#    'wine',
#    'spoon',
#    'red wine']},
#  {'image_id': 408696,
#   'question_id': 'A7MATFYMiNxpWLN7ucoWmS',
#   'answer': '',
#   'direct_answers': ['basement',
#    'basement',
#    'crawlspace',
#    'basement',
#    'attic',
#    'basement',
#    'bathroom',
#    'basement',
#    'attic',
#    'store']},
#  {'image_id': 183049,
#   'question_id': 'A9Pk4Az2eRMuSEgB8GnUBU',
#   'answer': '',
#   'direct_answers': ['mystery',
#    'thrillers',
#    'military',
#    'thriller fiction',
#    'thriller',
#    'non fiction',
#    'many books',
#    'thriller',
#    'triller',
#    'espionage']},
#  {'image_id': 91406,
#   'question_id': 'ACMY4KCmBjXQNimvG4dJhA',
#   'answer': '',
#   'direct_answers': ['four',
#    'four',
#    'four',
#    'four',
#    'four',
#    'four',
#    'four',
#    'four',
#    'four',
# ...
#   'question_id': 'hikczeyros8C4QajTVYThj',
#   'answer': 'isbees',
#   'direct_answers': ['frisbees',
#    'frisbee',
#    'frisbees',
#    'frisbee',
#    'frisbee',
#    'frisbee',
#    'frisbees',
#    'frisbee',
#    'frisbees',
#    'frisbees']},
#  {'image_id': 333745,
#   'question_id': 'hkMfnT4LEQi4HKPck6FVor',
#   'answer': '',
#   'direct_answers': ['malaysia',
#    'maylasia',
#    'malaysia',
#    'maylasia',
#    'maylasia',
#    'malaysia',
#    'malaysia',
#    'malaysia',
#    'malaysia',
#    'malaysia']},
#  {'image_id': 104669,
#   'question_id': 'hmfuC58r3K4Yg7EkMxJXXb',
#   'answer': '',
#   'direct_answers': ['potatoes',
#    'potatoes',
#    'potatoes',
#    'potatoes',
#    'potato',
#    'potato',
#    'potato',
#    'potatoes',
#    'potato',
#    'potatoes']},
#  {'image_id': 163682,
#   'question_id': 'hnKD5XstcaNYe6tjb6vCPe',
#   'answer': 'icago, il',
#   'direct_answers': ['office',
#    'at desk',
#    'office',
#    'office',
#    'office',
#    'office',
#    'at desk',
#    'office',
#    'office',
#    'office']},
#  {'image_id': 570539,
#   'question_id': 'hrbVpGvQvzUsT7sFzWQWXu',
#   'answer': 'com',
#   'direct_answers': ['video',
#    'movie',
#    'planet 51',
#    'movie',
#    'game',
#    'cinema',
#    'movie',
#    'cartoon',
#    'film',
#    'movie']},
#  {'image_id': 1993,
#   'question_id': 'hrzBKUpTCF5Bp7uvJbjv9Z',
#   'answer': '',
#   'direct_answers': ['purple',
#    'purple',
#    'purple',
#    'brown',
#    'purple',
#    'purple',
#    'brown',
#    'purple',
#    'purple',
#    'purple']},
#  {'image_id': 576955,
#   'question_id': 'hxRkeGBLz5CdxgnXSgiiH7',
#   'answer': 'oves',
#   'direct_answers': ['hoofs',
#    'hooves',
#    'hooves',
#    'hooves',
#    'hooves',
#    'hooves',
#    'hooves',
#    'hoofs',
#    'hooves',
#    'hooves']},
#  {'image_id': 186345,
#   'question_id': 'hzfzWaLVz2ASnBBWc77fxG',
#   'answer': 'ahorses',
#   'direct_answers': ['seahorses',
#    'seahorses',
#    'seahorses',
#    'seahorses',
#    'dragons',
#    'seahorses',
#    'seahorses',
#    'seahorses',
#    'seahorses',
#    'seahorses']},
#  {'image_id': 359833,
#   'question_id': 'i2ZhyTn4CzHyVxCjM6JFP5',
#   'answer': 'les',
#   'direct_answers': ['apples',
#    'apple',
#    'apples',
#    'apples',
#    'apple',
#    'apple',
#    'apples',
#    'fruit',
#    'fruits',
#    'apples']},
#  {'image_id': 180560,
#   'question_id': 'i2snYhswVVyhfgxn8DcGnk',
#   'answer': 'woman with the cake',
#   'direct_answers': ['open mouth',
#    'wearing coat',
#    'both',
#    'both',
#    'cake holder',
#    'cake holder',
#    'both',
#    'closest woman',
#    'women',
#    'left one']},
#  {'image_id': 138550,
#   'question_id': 'i9MJBUxa64ZL4vaG7hse5x',
#   'answer': 'hydrant',
#   'direct_answers': ['parking',
#    'parking',
#    'parking',
#    'parking',
#    'parking',
#    'vehicles',
#    'parking',
#    'parking',
#    'vehicles',
#    'vehicles']},
#  {'image_id': 503823,
#   'question_id': 'iEUBT5a5ajx5MR33EMkQVr',
#   'answer': '',
#   'direct_answers': ['canoes',
#    'boats',
#    'boats',
#    'canoes',
#    'boat',
#    'boats',
#    'boat',
#    'boats',
#    'boats',
#    'fishing boats']},
#  {'image_id': 25986,
#   'question_id': 'iL7gMCQ2U2vjmJWoyYc9wn',
#   'answer': '',
#   'direct_answers': ['foil',
#    'tin foil',
#    'foil',
#    'tin foil',
#    'tin foil',
#    'foil',
#    'aluminum foil',
#    'tin foil',
#    'tin foil',
#    'tin foil']},
#  {'image_id': 31093,
#   'question_id': 'iNDT4fYo9xeKBX6TrvtkVR',
#   'answer': '',
#   'direct_answers': ['falling',
#    'broken bone',
#    'scrapes',
#    'falling',
#    'death',
#    'broken bones',
#    'falling',
#    'falling',
#    'thrown away',
#    'broken bones']},
#  {'image_id': 438304,
#   'question_id': 'iSYpHGY6hdWo6qLQBbrENX',
#   'answer': 'idas',
#   'direct_answers': ['arthur ashe',
#    'stan smith',
#    'faruk marcos',
#    'john mcenroe',
#    'mcenroe',
#    'adidas',
#    'andre agassi',
#    'tiger',
#    'arthur ashe',
#    'andy murray']},
#  {'image_id': 264535,
#   'question_id': 'iXYYsBAjutihbRQuT3LVzn',
#   'answer': 'is looking down because he is thinking about something',
#   'direct_answers': ["he's reading",
#    'reading',
#    'reading',
#    'reading',
#    'reading book',
#    'reading book',
#    'reading',
#    'reading',
#    'reading book',
#    'reading']},
#  {'image_id': 230362,
#   'question_id': 'iepNGdTWvJFnPbHVTuKmLw',
#   'answer': 'boat',
#   'direct_answers': ['sailboats',
#    'sailboat',
#    'sailboat',
#    'sailing vessel',
#    'sailboat',
#    'sail',
#    'sail',
#    'sailboat',
#    'fishing',
#    'sailboat']},
#  {'image_id': 292236,
#   'question_id': 'ijeUcdVFHVYtTABEpPYJCR',
#   'answer': 'men are wearing a hat because they are waiting',
#   'direct_answers': ['unknown',
#    'conductor',
#    'signify role',
#    'uniform',
#    'design',
#    'cap',
#    'uniform requirement',
#    'train employees',
#    'uniform',
#    'uniform part']},
#  {'image_id': 33368,
#   'question_id': 'inA8DF895bDbH7gLhXnenH',
#   'answer': 'shoes',
#   'direct_answers': ['nike',
#    'tennis shoes',
#    'tennis',
#    'tennis',
#    'tennis shoes',
#    'tennis',
#    'nike',
#    'nike',
#    'nike',
#    'tennis']},
#  {'image_id': 505565,
#   'question_id': 'ioNZxNbwvEagLBwSYCmVkU',
#   'answer': 'ork',
#   'direct_answers': ['stork',
#    'pelican',
#    'pelican',
#    'pelican',
#    'pelican',
#    'flamingo',
#    'pelican',
#    'stork',
#    'egrit',
#    'ibis']},
#  {'image_id': 386912,
#   'question_id': 'iq9BaDbmL7bZfnXELtibFz',
#   'answer': 'desktop computer',
#   'direct_answers': ['imac',
#    'imac',
#    'apple',
#    'mac',
#    'imac',
#    'desktop',
#    'imac',
#    'imac',
#    'apple computer',
#    'apple']},
#  {'image_id': 357816,
#   'question_id': 'irhkgQFLQikZ9fY6LfKbKN',
#   'answer': 'ats',
#   'direct_answers': ['under armour',
#    'under armour',
#    'nike',
#    'under armour',
#    'under armor',
#    'under armour',
#    'ridell',
#    'under armour',
#    'underarmour',
#    'under armour']},
#  {'image_id': 379533,
#   'question_id': 'iriWmuGxQfwS4Uj8UE2ojD',
#   'answer': '',
#   'direct_answers': ['savannah',
#    'desert',
#    'field',
#    'africa',
#    'background',
#    'africa',
#    'outside',
#    'wild',
#    'field',
#    'savanna']},
#  {'image_id': 185802,
#   'question_id': 'isR9iC8cxoXvYQYBacRuzc',
#   'answer': 'ipe',
#   'direct_answers': ['medium',
#    'very',
#    'very',
#    'halfway',
#    'green',
#    'very',
#    'pull peel',
#    'very',
#    'very ripe',
#    'moderately ripe']},
#  {'image_id': 37988,
#   'question_id': 'j3G4tBe5ga2sVPS2yWYbFM',
#   'answer': '',
#   'direct_answers': ['return serve',
#    'serve ball',
#    'return serve',
#    'serve',
#    'hit ball',
#    'catch',
#    'serve',
#    'serve',
#    'return serve',
#    'retrieve ball']},
#  {'image_id': 3845,
#   'question_id': 'j4usZ4NoJf62hcBq4GCBc7',
#   'answer': '',
#   'direct_answers': ['japanese',
#    'chinese',
#    'asian',
#    'chinese',
#    'asian',
#    'stirfry',
#    'chinese',
#    'chinese',
#    'chinese',
#    'asian']},
#  {'image_id': 55167,
#   'question_id': 'j5HvFYT7fQSpvcuwoY7495',
#   'answer': '',
#   'direct_answers': ['canada',
#    'ukraine',
#    'ukraine',
#    'ukraine',
#    'unknown',
#    'ukraine',
#    'ukraine',
#    'ukraine',
#    'sweden',
#    'lakers flag']},
#  {'image_id': 279278,
#   'question_id': 'j5j6LUEzw383spcNXi7XhT',
#   'answer': 'skateboard',
#   'direct_answers': ['skateboard',
#    'skateboard',
#    'skateboard',
#    'ground',
#    'ground',
#    'skateboard',
#    'skateboard',
#    'skateboard',
#    'skateboard',
#    'skateboard']},
#  {'image_id': 479155,
#   'question_id': 'j6AP78GdCUYqzaxWmNS5MX',
#   'answer': '',
#   'direct_answers': ['produce',
#    'produce',
#    'fresh fruit',
#    'produce section',
#    'produce section',
#    'produce',
#    'produce',
#    'produce',
#    'fruit',
#    'produce']},
#  {'image_id': 425227,
#   'question_id': 'j6q58xPaDShNBgnj2kKpAP',
#   'answer': 'the beach',
#   'direct_answers': ['on beach',
#    'beach',
#    'beach',
#    'beach',
#    'beach',
#    'beach',
#    'beach',
#    'sand',
#    'near sea',
#    'on beach']},
#  {'image_id': 472375,
#   'question_id': 'j9ix7Egb5KJ7PkXttbbtdC',
#   'answer': 'is sitting',
#   'direct_answers': ['sitting',
#    'siting',
#    'being photographed',
#    'wearing helmet',
#    'wearing helmet',
#    'sitting',
#    'sitting',
#    'wearing helmet',
#    'sitting',
#    'sitting']},
#  {'image_id': 483667,
#   'question_id': 'jDicosLUWpypTQmQkRhC4W',
#   'answer': 'hat',
#   'direct_answers': ['top',
#    'top hat',
#    'top hat',
#    'fedora',
#    'top hat',
#    'top hat',
#    'top hat',
#    'tophat',
#    'top hat',
#    'fedora']},
#  {'image_id': 520910,
#   'question_id': 'jE3TsyErJ4eD8rPhTzBzb6',
#   'answer': "woman's eyes are looking at the camera",
#   'direct_answers': ['staring',
#    'looking',
#    'staring',
#    'opened',
#    'staring',
#    'staring',
#    'staring',
#    'looking',
#    'closed',
#    'staring']},
#  {'image_id': 463618,
#   'question_id': 'jENRJNFPp8S9aqLGkRfkiU',
#   'answer': 'living room',
#   'direct_answers': ['living room',
#    'living room',
#    'home',
#    'living room',
#    'home',
#    'home',
#    'living room',
#    'living room',
#    'family room',
#    'home']},
#  {'image_id': 298251,
#   'question_id': 'jJtrzZ4RRXKH8SSVmgw8tp',
#   'answer': '',
#   'direct_answers': ['field',
#    'savannah',
#    'field',
#    'field',
#    'wild',
#    'wildanimal parks',
#    'field',
#    'savannah',
#    'desert',
#    'field']},
#  {'image_id': 394510,
#   'question_id': 'jK2QtNn8nC2mC2E57bZv7L',
#   'answer': '',
#   'direct_answers': ['fall',
#    'fall',
#    'autumn',
#    'fall',
#    'fall',
#    'fall',
#    'summer time',
#    'fall',
#    'fall',
#    'fall']},
#  {'image_id': 201072,
#   'question_id': 'jKMHHLCYMYAARWrY2r4KHW',
#   'answer': 'left arm',
#   'direct_answers': ['right',
#    'right arm',
#    'right arm',
#    'right',
#    'right',
#    'right',
#    'left',
#    'right',
#    'right',
#    'right']},
#  {'image_id': 581206,
#   'question_id': 'jMvTvShVbt7rP82s3rRXxf',
#   'answer': "person's hands are clean from the food",
#   'direct_answers': ['paper',
#    'paper plate',
#    'tray',
#    'plate',
#    'paper tray',
#    'paper plate',
#    'walled dish',
#    'paper plate',
#    'tray',
#    'paper container']},
#  {'image_id': 534827,
#   'question_id': 'jQLQXdTab2NMEr4CHskSjQ',
#   'answer': 'cycle',
#   'direct_answers': ['moped',
#    'motorcycle',
#    'motorcycles',
#    'motorcycle',
#    'motorcycles',
#    'motorcycles',
#    'motorcycle',
#    'motorcycles',
#    'motorcycles',
#    'motorcycle']},
#  {'image_id': 163118,
#   'question_id': 'jQjEGnnPzL4AVqfBAfHvjq',
#   'answer': 'a gymnasium',
#   'direct_answers': ['basketball court',
#    'gym',
#    'gym',
#    'gym',
#    'indoor gym',
#    'gym',
#    'basketball court',
#    'gymnasium',
#    'gym',
#    'gym']},
#  {'image_id': 42178,
#   'question_id': 'jRxbsCVJxNtUMvsEBfpTaE',
#   'answer': '',
#   'direct_answers': ['freight train',
#    'tank car',
#    'freight train',
#    'cargo',
#    'cargo',
#    'freight',
#    'oil',
#    'freight',
#    'freight electric',
#    'long']},
#  {'image_id': 278463,
#   'question_id': 'jT7i37wypejYFkuDY3xLLg',
#   'answer': '',
#   'direct_answers': ['human',
#    'owner',
#    'pen',
#    'manchine',
#    'pen',
#    'human',
#    'person',
#    'student',
#    'pen',
#    'pen']},
#  {'image_id': 332351,
#   'question_id': 'jVXbihURQxsHwkTVByGBKj',
#   'answer': 'ers',
#   'direct_answers': ['waves',
#    'surfboards',
#    'surfboards',
#    'surfboards',
#    'surfboard',
#    'surf boards',
#    'surfboard',
#    'surf boards',
#    'surfboards',
#    'surf board']},
#  {'image_id': 546964,
#   'question_id': 'jZ6AjasusNaTDooYZHPv6L',
#   'answer': 'room',
#   'direct_answers': ['formal',
#    'formal',
#    'foyer',
#    'museum',
#    'royal',
#    'museum',
#    'salon',
#    'living toom',
#    'lobby',
#    'showcase']},
#  {'image_id': 356347,
#   'question_id': 'ja6pMKAxBoEM6Q9tvtsmMA',
#   'answer': '',
#   'direct_answers': ['metal',
#    'metal',
#    'aluminum',
#    'porcelain',
#    'metal',
#    'metal',
#    'aluminum',
#    'metal',
#    'metal',
#    'metal']},
#  {'image_id': 531495,
#   'question_id': 'jb2M9hwaHvK2itZac5i4tb',
#   'answer': 'ina',
#   'direct_answers': ['marina docks',
#    'marina',
#    'boats',
#    'boats',
#    'marina',
#    'docks',
#    'docks',
#    'boats',
#    'pier',
#    'port']},
#  {'image_id': 448263,
#   'question_id': 'jbdEbFFZDtMSrD3h32SFAp',
#   'answer': 'boy is using a glove to catch the ball',
#   'direct_answers': ['to catch',
#    'catching',
#    'catch ball',
#    'catch ball',
#    'catch ball',
#    'catch baseball',
#    'protect hand',
#    'ball catching',
#    'catching ball',
#    'baseball']},
#  {'image_id': 569917,
#   'question_id': 'jfuLWvGbtvRTnLYAPEE8pi',
#   'answer': '',
#   'direct_answers': ['two',
#    'two',
#    'two',
#    'two',
#    'two',
#    'two',
#    'two',
#    'two',
#    'two',
#    'two']},
#  {'image_id': 223747,
#   'question_id': 'jnEMGAZLdvFn9ZgBYUbAUX',
#   'answer': '',
#   'direct_answers': ['wake up',
#    'awaken',
#    'awaken',
#    'awaken',
#    'wake up',
#    'awaken',
#    'wake up',
#    'wake up',
#    'wake up',
#    'wake up']},
#  {'image_id': 534673,
#   'question_id': 'jnuckE6W2YqaueH7XL4ogy',
#   'answer': '',
#   'direct_answers': ['coast tour',
#    'coast tour',
#    'transportation',
#    'transportation',
#    'tours',
#    'coast tour',
#    'coast tour',
#    'transportation',
#    'coast tour',
#    'transportation']},
#  {'image_id': 58539,
#   'question_id': 'jqhSWKF72XwtaJGZH7XbS9',
#   'answer': '',
#   'direct_answers': ['two',
#    'two',
#    'two',
#    'two',
#    'two',
#    'two',
#    'two',
#    'two',
#    'two',
#    'two']},
#  {'image_id': 578871,
#   'question_id': 'jtqcU9Q9ToadtKDFM8p7mP',
#   'answer': 'rice',
#   'direct_answers': ['fried rice',
#    'fried rice',
#    'cereal',
#    'rice',
#    'rice',
#    'rice',
#    'pasta',
#    'rice',
#    'egg rice',
#    'rice']},
#  {'image_id': 160556,
#   'question_id': 'jvRoVpT79gh4dBU94qtsK8',
#   'answer': 'rowave',
#   'direct_answers': ['microwave',
#    'microwave',
#    'microwave',
#    'microwave',
#    'microwave',
#    'microwave',
#    'microwave',
#    'computer',
#    'computer',
#    'microwave']},
#  {'image_id': 2685,
#   'question_id': 'jyrnj3VZZGHVf5gYxzYmxA',
#   'answer': 'tasting',
#   'direct_answers': ['wine tasting',
#    'wine tasting',
#    'wine gallery',
#    'wine tasting',
#    'tasting',
#    'wine tasting',
#    'wine tasting',
#    'tasting',
#    'wine tasting',
#    'wine tasting']},
#  {'image_id': 74209,
#   'question_id': 'k3XafzjyDZn8GCzcH9BE5g',
#   'answer': '',
#   'direct_answers': ['six',
#    '12',
#    'six',
#    'six',
#    'six',
#    'twelve',
#    'six',
#    'at six',
#    'six',
#    'six']},
#  {'image_id': 365745,
#   'question_id': 'k8WjRvSCus9iQjUV6mPbCQ',
#   'answer': 'drink"',
#   'direct_answers': ['stella artois',
#    'stella artois',
#    'stella artois',
#    'beer',
#    'stella artois',
#    'stella artois',
#    'beer',
#    'stella artois',
#    'stella air tones',
#    'liquor']},
#  {'image_id': 567740,
#   'question_id': 'k8y3RfpAYmSuXDkcpiDQrx',
#   'answer': 'ing',
#   'direct_answers': ['laughing',
#    'posing',
#    'skiing',
#    'posing',
#    'skiing',
#    'skiing',
#    'skiing',
#    'skiing',
#    'smiling',
#    'skiing']},
#  {'image_id': 127530,
#   'question_id': 'kHb4MjmU3bZTRY5qJSrZe7',
#   'answer': 'serve',
#   'direct_answers': ['backhand',
#    'tennis',
#    'tennis ball',
#    'forehand',
#    'right hand',
#    'forehand',
#    'forehand',
#    'backhand',
#    'swing',
#    'forehand']},
#  {'image_id': 159791,
#   'question_id': 'kLeQDtR5HUh6L8dbvEzhGe',
#   'answer': '',
#   'direct_answers': ['stove/oven',
#    'stove',
#    'range',
#    'stove',
#    'oven',
#    'stove',
#    'oven',
#    'stove',
#    'stove',
#    'oven']},
#  {'image_id': 274687,
#   'question_id': 'kP9etcrALtsYL363dVhT5Y',
#   'answer': 'long bar of the bicycle is the handlebar',
#   'direct_answers': ['top tube',
#    'frame',
#    'handlebar',
#    'handle',
#    'frame',
#    'black',
#    'stearing',
#    'frame',
#    'bike lock',
#    'handle']},
#  {'image_id': 99053,
#   'question_id': 'kZWuYe4HefJH33d7GCb4Tk',
#   'answer': '',
#   'direct_answers': ['japanese',
#    'chinese',
#    'asian',
#    'chinese',
#    'asia',
#    'chinese',
#    'china',
#    'chinese',
#    'chinese food',
#    'asian']},
#  {'image_id': 133645,
#   'question_id': 'kaocqcY3CESTstFs9Bd4Pg',
#   'answer': '',
#   'direct_answers': ['early evening',
#    'dusk',
#    'evening',
#    'evening',
#    'evening',
#    'evening',
#    'night',
#    'dusk',
#    'twilight',
#    'evening']},
#  {'image_id': 260470,
#   'question_id': 'kgUHGxPt2H4SrR5Nb9be44',
#   'answer': '',
#   'direct_answers': ['shirt',
#    'sweater',
#    'sweater',
#    'shirt',
#    'shirt',
#    'shirt',
#    'shirt',
#    'shirt',
#    'sweater',
#    'shirt']},
#  {'image_id': 309678,
#   'question_id': 'khkvYrTt2t5MTJyJvBNiDR',
#   'answer': '',
#   'direct_answers': ['cheese',
#    'marination',
#    'tomato',
#    'tomatoes',
#    'tomato',
#    'tomato',
#    'fruit',
#    'tomato',
#    'tomato paste',
#    'tomato']},
#  ...]

# %%
save_results_to_file(blip_mc_result, '../Jan-ML/blip2-opt-2.7b_val_results_mc.json')
save_results_to_file(blip_da_result, '../Jan-ML/blip2-opt-2.7b_val_results_da.json')

# %%
eval_vqa(blip_da_result, val_dataset)
# Out:
# 4.192139737991267

# %%
eval_vqa(blip_mc_result, val_dataset, mc=True)
# Out:
# 25.065502183406114

# %% [markdown]
# # Molmo

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
processor = AutoProcessor.from_pretrained(
    'allenai/MolmoE-1B-0924',
    trust_remote_code=True,
    torch_dtype='auto',
    device_map='auto'
)
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPTNeoXTokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.

# %%
# load the model
model = AutoModelForCausalLM.from_pretrained(
    'allenai/MolmoE-1B-0924',
    trust_remote_code=True,
    torch_dtype='auto',
    device_map='auto'
)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# File ~/miniconda3/envs/qaprompts/lib/python3.9/site-packages/transformers/modeling_utils.py:575, in load_state_dict(checkpoint_file, is_quantized)
#     574     weights_only_kwarg = {"weights_only": True} if is_torch_greater_or_equal_than_1_13 else {}
# --> 575     return torch.load(
#     576         checkpoint_file,
#     577         map_location=map_location,
#     578         **weights_only_kwarg,
#     579         **extra_args,
#     580     )
#     581 except Exception as e:
#
# File ~/miniconda3/envs/qaprompts/lib/python3.9/site-packages/torch/serialization.py:788, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     787     except RuntimeError as e:
# --> 788         raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
#     789 return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#
# UnpicklingError: Weights only load failed. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution.Do it only if you get the file from a trusted source. WeightsUnpickler error: Unsupported class torch._tensor._rebuild_from_type_v2
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~/miniconda3/envs/qaprompts/lib/python3.9/site-packages/transformers/modeling_utils.py:584, in load_state_dict(checkpoint_file, is_quantized)
#     583 with open(checkpoint_file) as f:
# --> 584     if f.read(7) == "version":
#     585         raise OSError(
#     586             "You seem to have cloned a repository without having git-lfs installed. Please install "
#     587             "git-lfs and run `git lfs install` followed by `git lfs pull` in the folder "
#     588             "you cloned."
#     589         )
#
# File ~/miniconda3/envs/qaprompts/lib/python3.9/codecs.py:322, in BufferedIncrementalDecoder.decode(self, input, final)
#     321 data = self.buffer + input
# --> 322 (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323 # keep undecoded input until the next call
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 64: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 2
#       1 # load the model
# ----> 2 model = AutoModelForCausalLM.from_pretrained(
#       3     'allenai/MolmoE-1B-0924',
#       4     trust_remote_code=True,
#       5     torch_dtype='auto',
#       6     device_map='auto'
#       7 )
#
# File ~/miniconda3/envs/qaprompts/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py:559, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     557     cls.register(config.__class__, model_class, exist_ok=True)
#     558     model_class = add_generation_mixin_to_remote_model(model_class)
# --> 559     return model_class.from_pretrained(
#     560         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     561     )
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
#
# File ~/miniconda3/envs/qaprompts/lib/python3.9/site-packages/transformers/modeling_utils.py:3814, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3811 if from_pt:
#    3812     if not is_sharded and state_dict is None:
#    3813         # Time to load the checkpoint
# -> 3814         state_dict = load_state_dict(resolved_archive_file)
#    3816     # set dtype to instantiate the model under:
#    3817     # 1. If torch_dtype is not None, we use that dtype
#    3818     # 2. If torch_dtype is "auto", we auto-detect dtype from the loaded state_dict, by checking its first
#    3819     #    weights entry that is of a floating type - we assume all floating dtype weights are of the same dtype
#    3820     # we also may have config.torch_dtype available, but we won't rely on it till v5
#    3821     dtype_orig = None
#
# File ~/miniconda3/envs/qaprompts/lib/python3.9/site-packages/transformers/modeling_utils.py:596, in load_state_dict(checkpoint_file, is_quantized)
#     591             raise ValueError(
#     592                 f"Unable to locate the file {checkpoint_file} which is necessary to load this pretrained "
#     593                 "model. Make sure you have saved the model properly."
#     594             ) from e
#     595 except (UnicodeDecodeError, ValueError):
# --> 596     raise OSError(
#     597         f"Unable to load weights from pytorch checkpoint file for '{checkpoint_file}' "
#     598         f"at '{checkpoint_file}'. "
#     599         "If you tried to load a PyTorch model from a TF 2.0 checkpoint, please set from_tf=True."
#     600     )
#
# OSError: Unable to load weights from pytorch checkpoint file for '/usr1/data/models_cache/hub/models--allenai--MolmoE-1B-0924/snapshots/03d86d0fc2cc9a8840f92c0df54d178d08b86be5/pytorch_model.bin' at '/usr1/data/models_cache/hub/models--allenai--MolmoE-1B-0924/snapshots/03d86d0fc2cc9a8840f92c0df54d178d08b86be5/pytorch_model.bin'. If you tried to load a PyTorch model from a TF 2.0 checkpoint, please set from_tf=True.

# %%
conversation = [
    {
      "role": "user",
      "content": [
          {"type": "text", "text": "What does the label 15 represent? (1) lava (2) core (3) tunnel (4) ash cloud"},
          {"type": "image"},
        ],
    },
]
processor = AutoProcessor.from_pretrained(model_id)

prompt = processor.apply_chat_template(conversation, add_generation_prompt=True)

outputs = pipe(image, prompt=prompt, generate_kwargs={"max_new_tokens": 200})
print(outputs)

# %% [markdown]
# # LLaVA

# %%
model_id = "llava-hf/llava-1.5-7b-hf"
model = LlavaForConditionalGeneration.from_pretrained(
    model_id, 
    torch_dtype=torch.float16, 
    low_cpu_mem_usage=True, 
    cache_dir="/usr1/data/models_cache"
).to(0)

processor = AutoProcessor.from_pretrained(model_id)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
print(dir(processor))
# Out:
# ['__annotations__', '__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_auto_class', '_create_repo', '_get_arguments_from_pretrained', '_get_files_timestamps', '_merge_kwargs', '_upload_modified_files', 'apply_chat_template', 'attributes', 'batch_decode', 'chat_template', 'decode', 'feature_extractor_class', 'from_args_and_dict', 'from_pretrained', 'get_processor_dict', 'image_processor', 'image_processor_class', 'image_token', 'model_input_names', 'optional_attributes', 'optional_call_args', 'patch_size', 'prepare_and_validate_optional_call_args', 'push_to_hub', 'register_for_auto_class', 'save_pretrained', 'to_dict', 'to_json_file', 'to_json_string', 'tokenizer', 'tokenizer_class', 'valid_kwargs', 'validate_init_kwargs', 'vision_feature_select_strategy']

# %%
conversation = [
    {

      "role": "user",
      "content": [
          {"type": "text", "text": "What are these?"},
          {"type": "image"},
        ],
    },
]
prompt = processor.apply_chat_template(conversation, add_generation_prompt=True)

image_file = "http://images.cocodataset.org/val2017/000000039769.jpg"
raw_image = Image.open(requests.get(image_file, stream=True).raw)
inputs = processor(images=raw_image, text=prompt, return_tensors='pt').to(0, torch.float16)

output = model.generate(**inputs, max_new_tokens=200, do_sample=False)
decoded_output = processor.decode(output[0][2:], skip_special_tokens=True)
# Out:
# Expanding inputs for image tokens in LLaVa should be done in processing. Please add `patch_size` and `vision_feature_select_strategy` to the model's processing config or set directly with `processor.patch_size = {{patch_size}}` and processor.vision_feature_select_strategy = {{vision_feature_select_strategy}}`. Using processors without these attributes in the config is deprecated and will throw an error in v4.47.
# Expanding inputs for image tokens in LLaVa should be done in processing. Please add `patch_size` and `vision_feature_select_strategy` to the model's processing config or set directly with `processor.patch_size = {{patch_size}}` and processor.vision_feature_select_strategy = {{vision_feature_select_strategy}}`. Using processors without these attributes in the config is deprecated and will throw an error in v4.47.
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)

# %%
output
# Out:
# tensor([[    1,  3148,  1001, 29901, 29871, 32000, 29871,    13,  5618,   526,
#           1438, 29973,   319,  1799,  9047, 13566, 29901,  4525,   526,  1023,
#            274,  1446, 19214,   373,   263,   282,   682,   274,  3222, 29889,
#              2]], device='cuda:0')

# %%
aokvqa_dir = os.getenv('AOKVQA_DIR')
val_dataset = load_aokvqa(aokvqa_dir, 'val')

# %%
dataset_example = val_dataset[0]
image_path = get_coco_path('val', dataset_example['image_id'], coco_dir)

# %%
dataset_example
# Out:
# {'split': 'val',
#  'image_id': 461751,
#  'question_id': '22jbM6gDxdaMaunuzgrsBB',
#  'question': "What is in the motorcyclist's mouth?",
#  'choices': ['toothpick', 'food', 'popsicle stick', 'cigarette'],
#  'correct_choice_idx': 3,
#  'direct_answers': ['cigarette',
#   'cigarette',
#   'cigarette',
#   'cigarette',
#   'cigarette',
#   'cigarette',
#   'cigarette',
#   'cigarette',
#   'cigarette',
#   'cigarette'],
#  'difficult_direct_answer': False,
#  'rationales': ["He's smoking while riding.",
#   'The motorcyclist has a lit cigarette in his mouth while he rides on the street.',
#   'The man is smoking.']}

# %%
image_path
# Out:
# '/usr1/data/mingqia2/coco/val2017/000000461751.jpg'

# %%
def llava_pipeline(val_dataset, coco_dir, output_file, batch_size=100, split='val', mc=False):
    results = []
    total_items = len(val_dataset)
    
    for idx, item in tqdm(enumerate(val_dataset), total=len(val_dataset)):
        image_id = item['image_id']
        question_id = item['question_id']
        if mc:
            choices = item['choices']
            choices_formatted = " ".join([f"({i+1}) {choice}" for i, choice in enumerate(choices)])
            question = item['question'] + " " + choices_formatted + " Please return only the chosen choice number as the answer."
        else:
            question = item['question'] + " Please return only the key word or phrase as the answer, not a full sentence."
        
        image_path = get_coco_path(split, image_id, coco_dir)

        # Load the image from the local path
        raw_image = Image.open(image_path)
        # Create conversation template with the question
        conversation = [
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": question},
                    {"type": "image"},
                ],
            },
        ]
        prompt = processor.apply_chat_template(conversation, add_generation_prompt=True)
        inputs = processor(images=raw_image, text=prompt, return_tensors='pt').to(0, torch.float16)

        # Run the model and generate output
        output = model.generate(**inputs, max_new_tokens=10, do_sample=False)
        decoded_output = processor.decode(output[0][2:], skip_special_tokens=True)

        # Store the results
        result = {
            "image_id": image_id,
            "question_id": question_id,
            "answer": decoded_output
        }
        results.append(result)

        if (idx + 1) % batch_size == 0 or (idx + 1) == total_items:
            save_results_to_file(results, output_file)
    # return results

# %%
train_dataset = load_aokvqa(aokvqa_dir, 'train')
len(train_dataset)
# Out:
# 17056

# %%
output_file = 'llava1.5-7b_val_results_da.json'
llava_pipeline(val_dataset, coco_dir, output_file, batch_size=100, split='val')
# Out:
# 100%|██████████| 1145/1145 [03:40<00:00,  5.19it/s]

# %%
output_file = 'llava1.5-7b_val_results_mc.json'
llava_pipeline(val_dataset, coco_dir, output_file, batch_size=100, split='val', mc=True)
# Out:
# 100%|██████████| 1145/1145 [03:51<00:00,  4.96it/s]

# %%
llava_mc_result = process_results('llava1.5-7b_val_results_mc.json', val_dataset, mc=True)

# %%
llava_da_result = process_results('llava1.5-7b_val_results_da.json', val_dataset)

# %%
save_results_to_file(llava_mc_result, 'llava1.5-7b_val_results_mc.json')
save_results_to_file(llava_da_result, 'llava1.5-7b_val_results_da.json')

# %%
llava_mc_path = "llava1.5-7b_val_results_mc.json"
llava_da_path = "llava1.5-7b_val_results_da.json"
with open(llava_mc_path, 'r') as f:
    llava_mc_result = json.load(f)
    
with open(llava_da_path, 'r') as f:
    llava_da_result = json.load(f)

# %%
eval_vqa(llava_da_result, val_dataset)
# Out:
# 58.16593886462881

# %%
eval_vqa(llava_mc_result, val_dataset, mc=True)
# Out:
# 25.065502183406114
